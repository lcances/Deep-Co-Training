# %% [markdown]
# # import

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
os.environ["MKL_NUM_THREADS"] = "2"
os.environ["NUMEXPR_NU M_THREADS"] = "2"
os.environ["OMP_NUM_THREADS"] = "2"
import time

import numpy as np
import torch
import torch.nn as nn
import torch.utils.data as data
import torch.nn.functional as F
from torch.optim.lr_scheduler import LambdaLR
from torch.utils.tensorboard import SummaryWriter

# %%
from ubs8k.datasetManager import DatasetManager
from ubs8k.datasets import Dataset


import sys
sys.path.append("../..")

from util.utils import reset_seed, get_datetime, get_model_from_name
from util.checkpoint import CheckPoint
from metric_utils.metrics import CategoricalAccuracy, FScore, ContinueAverage

from UrbanSound8k.models import ScalableCnn

# %% [markdown]
# # Arguments

# %%
import argparse
parser = argparse.ArgumentParser()
# dataset related parameters
parser.add_argument("-d", "--dataset_root", default="../../datasets/ubs8k", type=str)
parser.add_argument("--supervised_ratio", default=1.0, type=float)
parser.add_argument("-t", "--train_folds", nargs="+", default=[1, 2, 3, 4, 5, 6, 7, 8, 9], type=int)
parser.add_argument("-v", "--val_folds", nargs="+", default=[10], type=int)

# learning parameters
parser.add_argument("--model", default="cnn0", type=str)
parser.add_argument("--batch_size", default=32, type=int)
parser.add_argument("--nb_epoch", default=100, type=int)
parser.add_argument("--learning_rate", default=0.003, type=int)

# compound scaling parameters
parser.add_argument("-a", "--alpha", default=1.0, type=float)
parser.add_argument("-b", "--beta", default=1.0, type=float)
parser.add_argument("-g", "--gamma", default=1.0, type=float)
parser.add_argument("-p", "--phi", default=1.0, type=float)

# extra utility parameters
parser.add_argument("--checkpoint_path", default="../../model_save/ubs8k/full_supervised_test", type=str)
parser.add_argument("--resume", action="store_true", default=False)
parser.add_argument("--tensorboard_path", default="../../tensorboard/ubs8k/full_supervised_test", type=str)
parser.add_argument("--tensorboard_sufix", default="", type=str)

args = parser.parse_args("")

# %% [markdown]
# # initialisation

# %%
reset_seed(1234)

# %%
valid_scales = []
scales = np.linspace(1.0, 2.0, 15)
tolerance = 0.05

for a in scales:
    for b in scales:
        for c in scales:
            v = a * b**2 * c**2
            
            if v-tolerance < 2 < v+tolerance:
                valid_scales.append((a, b, c))

# %%
len(valid_scales), valid_scales
# Out:
# (20,
#  [(1.0, 1.0, 1.4285714285714286),
#   (1.0, 1.4285714285714286, 1.0),
#   (1.0714285714285714, 1.0, 1.3571428571428572),
#   (1.0714285714285714, 1.0714285714285714, 1.2857142857142856),
#   (1.0714285714285714, 1.2857142857142856, 1.0714285714285714),
#   (1.0714285714285714, 1.3571428571428572, 1.0),
#   (1.2142857142857142, 1.0, 1.2857142857142856),
#   (1.2142857142857142, 1.2857142857142856, 1.0),
#   (1.3571428571428572, 1.0, 1.2142857142857142),
#   (1.3571428571428572, 1.0714285714285714, 1.1428571428571428),
#   (1.3571428571428572, 1.1428571428571428, 1.0714285714285714),
#   (1.3571428571428572, 1.2142857142857142, 1.0),
#   (1.5, 1.0, 1.1428571428571428),
#   (1.5, 1.0714285714285714, 1.0714285714285714),
#   (1.5, 1.1428571428571428, 1.0),
#   (1.7142857142857142, 1.0, 1.0714285714285714),
#   (1.7142857142857142, 1.0714285714285714, 1.0),
#   (1.7857142857142856, 1.0, 1.0714285714285714),
#   (1.7857142857142856, 1.0714285714285714, 1.0),
#   (2.0, 1.0, 1.0)])

# %%
print("scales=(")
for (a, b, g) in valid_scales:
    print("\t\"-a %f -b %f -g %f\" \\" % (a, b, g))
print(")")
# Out:
# scales=(
# 	"-a 1.000000 -b 1.000000 -g 1.428571" \
# 	"-a 1.000000 -b 1.428571 -g 1.000000" \
# 	"-a 1.071429 -b 1.000000 -g 1.357143" \
# 	"-a 1.071429 -b 1.071429 -g 1.285714" \
# 	"-a 1.071429 -b 1.285714 -g 1.071429" \
# 	"-a 1.071429 -b 1.357143 -g 1.000000" \
# 	"-a 1.214286 -b 1.000000 -g 1.285714" \
# 	"-a 1.214286 -b 1.285714 -g 1.000000" \
# 	"-a 1.357143 -b 1.000000 -g 1.214286" \
# 	"-a 1.357143 -b 1.071429 -g 1.142857" \
# 	"-a 1.357143 -b 1.142857 -g 1.071429" \
# 	"-a 1.357143 -b 1.214286 -g 1.000000" \
# 	"-a 1.500000 -b 1.000000 -g 1.142857" \
# 	"-a 1.500000 -b 1.071429 -g 1.071429" \
# 	"-a 1.500000 -b 1.142857 -g 1.000000" \
# 	"-a 1.714286 -b 1.000000 -g 1.071429" \
# 	"-a 1.714286 -b 1.071429 -g 1.000000" \
# 	"-a 1.785714 -b 1.000000 -g 1.071429" \
# 	"-a 1.785714 -b 1.071429 -g 1.000000" \
# 	"-a 2.000000 -b 1.000000 -g 1.000000" \
# )

# %% [markdown]
# # Prepare the dataset

# %%
audio_root = os.path.join(args.dataset_root, "audio")
metadata_root = os.path.join(args.dataset_root, "metadata")
all_folds = args.train_folds + args.val_folds

manager = DatasetManager(
    metadata_root, audio_root,
    folds=all_folds,
    verbose=2
)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
# prepare the sampler with the specified number of supervised file
train_dataset = Dataset(manager, folds=args.train_folds, cached=True)
val_dataset = Dataset(manager, folds=args.val_folds, cached=True)

# %% [markdown]
# # Prep model

# %% [markdown]
# ## test if model is valid

# %%
from torchsummaryX import summary

common_parameters = dict(
     dataset = manager,
     initial_conv_inputs=[1, 24, 48, 48],
     initial_conv_outputs=[24, 48, 48, 48],
     initial_linear_inputs=[720, ],
     initial_linear_outputs=[10, ],
     initial_resolution=[64, 173],
     round_up = False,
)

for (a, b, g) in valid_scales:
    model = ScalableCnn(compound_scales=(a, b, g), **common_parameters)
    
    new_res = model.scaled_resolution
    input_tensor = torch.zeros((1, new_res[0], new_res[1]), dtype=torch.float)
    
    s = summary(model, input_tensor)
# Out:
# new scaled resolution:  (91, 247)
# new feature extraction function generation: hop_length = 357
# new conv layers:
# inputs:  [1, 24, 48, 48]
# ouputs:  [24, 48, 48, 48]
# new dense layers:
# inputs:  [3600]
# ouputs:  [10]
# ==================================================================================
#                                Kernel Shape      Output Shape   Params  \
# Layer
# 0_features.0.Conv2d_0         [1, 24, 3, 3]  [1, 24, 91, 247]    240.0
# 1_features.0.BatchNorm2d_1             [24]  [1, 24, 91, 247]     48.0
# 2_features.0.Dropout2d_2                  -  [1, 24, 91, 247]        -
# 3_features.0.ReLU6_3                      -  [1, 24, 91, 247]        -
# 4_features.0.MaxPool2d_4                  -  [1, 24, 45, 123]        -
# 5_features.1.Conv2d_0        [24, 48, 3, 3]  [1, 48, 45, 123]  10.416k
# 6_features.1.BatchNorm2d_1             [48]  [1, 48, 45, 123]     96.0
# 7_features.1.Dropout2d_2                  -  [1, 48, 45, 123]        -
# 8_features.1.ReLU6_3                      -  [1, 48, 45, 123]        -
# 9_features.1.MaxPool2d_4                  -   [1, 48, 22, 61]        -
# 10_features.2.Conv2d_0       [48, 48, 3, 3]   [1, 48, 22, 61]  20.784k
# 11_features.2.BatchNorm2d_1            [48]   [1, 48, 22, 61]     96.0
# 12_features.2.Dropout2d_2                 -   [1, 48, 22, 61]        -
# 13_features.2.ReLU6_3                     -   [1, 48, 22, 61]        -
# 14_features.2.MaxPool2d_4                 -   [1, 48, 11, 30]        -
# 15_features.3.Conv2d_0       [48, 48, 3, 3]   [1, 48, 11, 30]  20.784k
# 16_features.3.BatchNorm2d_1            [48]   [1, 48, 11, 30]     96.0
# 17_features.3.Dropout2d_2                 -   [1, 48, 11, 30]        -
# 18_features.3.ReLU6_3                     -   [1, 48, 11, 30]        -
# 19_features.3.MaxPool2d_4                 -    [1, 48, 5, 15]        -
# 20_classifier.Flatten_0                   -         [1, 3600]        -
# 21_classifier.Dropout_1                   -         [1, 3600]        -
# 22_classifier.Linear_2           [3600, 10]           [1, 10]   36.01k
#
#                               Mult-Adds
# Layer
# 0_features.0.Conv2d_0         4.855032M
# 1_features.0.BatchNorm2d_1         24.0
# 2_features.0.Dropout2d_2              -
# 3_features.0.ReLU6_3                  -
# 4_features.0.MaxPool2d_4              -
# 5_features.1.Conv2d_0         57.38688M
# 6_features.1.BatchNorm2d_1         48.0
# 7_features.1.Dropout2d_2              -
# 8_features.1.ReLU6_3                  -
# 9_features.1.MaxPool2d_4              -
# 10_features.2.Conv2d_0       27.827712M
# 11_features.2.BatchNorm2d_1        48.0
# 12_features.2.Dropout2d_2             -
# 13_features.2.ReLU6_3                 -
# 14_features.2.MaxPool2d_4             -
# 15_features.3.Conv2d_0         6.84288M
# 16_features.3.BatchNorm2d_1        48.0
# 17_features.3.Dropout2d_2             -
# 18_features.3.ReLU6_3                 -
# 19_features.3.MaxPool2d_4             -
# 20_classifier.Flatten_0               -
# 21_classifier.Dropout_1               -
# 22_classifier.Linear_2            36.0k
# ----------------------------------------------------------------------------------
#                           Totals
# Total params              88.57k
# Trainable params          88.57k
# Non-trainable params         0.0
# Mult-Adds             96.948672M
# ==================================================================================
# new scaled resolution:  (64, 173)
# new feature extraction function generation: hop_length = 509
# new conv layers:
# inputs:  [1, 34, 68, 68]
# ouputs:  [34, 68, 68, 68]
# new dense layers:
# inputs:  [2720]
# ouputs:  [10]
# ==================================================================================
#                                Kernel Shape      Output Shape   Params  \
# Layer
# 0_features.0.Conv2d_0         [1, 34, 3, 3]  [1, 34, 64, 173]    340.0
# 1_features.0.BatchNorm2d_1             [34]  [1, 34, 64, 173]     68.0
# 2_features.0.Dropout2d_2                  -  [1, 34, 64, 173]        -
# 3_features.0.ReLU6_3                      -  [1, 34, 64, 173]        -
# 4_features.0.MaxPool2d_4                  -   [1, 34, 32, 86]        -
# 5_features.1.Conv2d_0        [34, 68, 3, 3]   [1, 68, 32, 86]  20.876k
# 6_features.1.BatchNorm2d_1             [68]   [1, 68, 32, 86]    136.0
# 7_features.1.Dropout2d_2                  -   [1, 68, 32, 86]        -
# 8_features.1.ReLU6_3                      -   [1, 68, 32, 86]        -
# 9_features.1.MaxPool2d_4                  -   [1, 68, 16, 43]        -
# 10_features.2.Conv2d_0       [68, 68, 3, 3]   [1, 68, 16, 43]  41.684k
# 11_features.2.BatchNorm2d_1            [68]   [1, 68, 16, 43]    136.0
# 12_features.2.Dropout2d_2                 -   [1, 68, 16, 43]        -
# 13_features.2.ReLU6_3                     -   [1, 68, 16, 43]        -
# 14_features.2.MaxPool2d_4                 -    [1, 68, 8, 21]        -
# 15_features.3.Conv2d_0       [68, 68, 3, 3]    [1, 68, 8, 21]  41.684k
# 16_features.3.BatchNorm2d_1            [68]    [1, 68, 8, 21]    136.0
# 17_features.3.Dropout2d_2                 -    [1, 68, 8, 21]        -
# 18_features.3.ReLU6_3                     -    [1, 68, 8, 21]        -
# 19_features.3.MaxPool2d_4                 -    [1, 68, 4, 10]        -
# 20_classifier.Flatten_0                   -         [1, 2720]        -
# 21_classifier.Dropout_1                   -         [1, 2720]        -
# 22_classifier.Linear_2           [2720, 10]           [1, 10]   27.21k
#
#                               Mult-Adds
# Layer
# 0_features.0.Conv2d_0         3.388032M
# 1_features.0.BatchNorm2d_1         34.0
# 2_features.0.Dropout2d_2              -
# 3_features.0.ReLU6_3                  -
# 4_features.0.MaxPool2d_4              -
# 5_features.1.Conv2d_0        57.263616M
# 6_features.1.BatchNorm2d_1         68.0
# 7_features.1.Dropout2d_2              -
# 8_features.1.ReLU6_3                  -
# 9_features.1.MaxPool2d_4              -
# 10_features.2.Conv2d_0       28.631808M
# 11_features.2.BatchNorm2d_1        68.0
# 12_features.2.Dropout2d_2             -
# 13_features.2.ReLU6_3                 -
# 14_features.2.MaxPool2d_4             -
# 15_features.3.Conv2d_0        6.991488M
# 16_features.3.BatchNorm2d_1        68.0
# 17_features.3.Dropout2d_2             -
# 18_features.3.ReLU6_3                 -
# 19_features.3.MaxPool2d_4             -
# 20_classifier.Flatten_0               -
# 21_classifier.Dropout_1               -
# 22_classifier.Linear_2            27.2k
# ----------------------------------------------------------------------------------
#                           Totals
# Total params             132.27k
# Trainable params         132.27k
# Non-trainable params         0.0
# Mult-Adds             96.302382M
# ==================================================================================
# new scaled resolution:  (86, 234)
# new feature extraction function generation: hop_length = 376
# new conv layers:
# inputs:  [1, 24, 48, 48]
# ouputs:  [24, 48, 48, 48]
# new dense layers:
# inputs:  [3360]
# ouputs:  [10]
# ==================================================================================
#                                Kernel Shape      Output Shape   Params  \
# Layer
# 0_features.0.Conv2d_0         [1, 24, 3, 3]  [1, 24, 86, 234]    240.0
# 1_features.0.BatchNorm2d_1             [24]  [1, 24, 86, 234]     48.0
# 2_features.0.Dropout2d_2                  -  [1, 24, 86, 234]        -
# 3_features.0.ReLU6_3                      -  [1, 24, 86, 234]        -
# 4_features.0.MaxPool2d_4                  -  [1, 24, 43, 117]        -
# 5_features.1.Conv2d_0        [24, 48, 3, 3]  [1, 48, 43, 117]  10.416k
# 6_features.1.BatchNorm2d_1             [48]  [1, 48, 43, 117]     96.0
# 7_features.1.Dropout2d_2                  -  [1, 48, 43, 117]        -
# 8_features.1.ReLU6_3                      -  [1, 48, 43, 117]        -
# 9_features.1.MaxPool2d_4                  -   [1, 48, 21, 58]        -
# 10_features.2.Conv2d_0       [48, 48, 3, 3]   [1, 48, 21, 58]  20.784k
# 11_features.2.BatchNorm2d_1            [48]   [1, 48, 21, 58]     96.0
# 12_features.2.Dropout2d_2                 -   [1, 48, 21, 58]        -
# 13_features.2.ReLU6_3                     -   [1, 48, 21, 58]        -
# 14_features.2.MaxPool2d_4                 -   [1, 48, 10, 29]        -
# 15_features.3.Conv2d_0       [48, 48, 3, 3]   [1, 48, 10, 29]  20.784k
# 16_features.3.BatchNorm2d_1            [48]   [1, 48, 10, 29]     96.0
# 17_features.3.Dropout2d_2                 -   [1, 48, 10, 29]        -
# 18_features.3.ReLU6_3                     -   [1, 48, 10, 29]        -
# 19_features.3.MaxPool2d_4                 -    [1, 48, 5, 14]        -
# 20_classifier.Flatten_0                   -         [1, 3360]        -
# 21_classifier.Dropout_1                   -         [1, 3360]        -
# 22_classifier.Linear_2           [3360, 10]           [1, 10]   33.61k
#
#                               Mult-Adds
# Layer
# 0_features.0.Conv2d_0         4.346784M
# 1_features.0.BatchNorm2d_1         24.0
# 2_features.0.Dropout2d_2              -
# 3_features.0.ReLU6_3                  -
# 4_features.0.MaxPool2d_4              -
# 5_features.1.Conv2d_0        52.161408M
# 6_features.1.BatchNorm2d_1         48.0
# 7_features.1.Dropout2d_2              -
# 8_features.1.ReLU6_3                  -
# 9_features.1.MaxPool2d_4              -
# 10_features.2.Conv2d_0       25.256448M
# 11_features.2.BatchNorm2d_1        48.0
# 12_features.2.Dropout2d_2             -
# 13_features.2.ReLU6_3                 -
# 14_features.2.MaxPool2d_4             -
# 15_features.3.Conv2d_0         6.01344M
# 16_features.3.BatchNorm2d_1        48.0
# 17_features.3.Dropout2d_2             -
# 18_features.3.ReLU6_3                 -
# 19_features.3.MaxPool2d_4             -
# 20_classifier.Flatten_0               -
# 21_classifier.Dropout_1               -
# 22_classifier.Linear_2            33.6k
# ----------------------------------------------------------------------------------
#                           Totals
# Total params              86.17k
# Trainable params          86.17k
# Non-trainable params         0.0
# Mult-Adds             87.811848M
# ==================================================================================
# new scaled resolution:  (82, 222)
# new feature extraction function generation: hop_length = 397
# new conv layers:
# inputs:  [1, 25, 51, 51]
# ouputs:  [25, 51, 51, 51]
# new dense layers:
# inputs:  [3315]
# ouputs:  [10]
# ==================================================================================
#                                Kernel Shape      Output Shape   Params  \
# Layer
# 0_features.0.Conv2d_0         [1, 25, 3, 3]  [1, 25, 82, 222]    250.0
# 1_features.0.BatchNorm2d_1             [25]  [1, 25, 82, 222]     50.0
# 2_features.0.Dropout2d_2                  -  [1, 25, 82, 222]        -
# 3_features.0.ReLU6_3                      -  [1, 25, 82, 222]        -
# 4_features.0.MaxPool2d_4                  -  [1, 25, 41, 111]        -
# 5_features.1.Conv2d_0        [25, 51, 3, 3]  [1, 51, 41, 111]  11.526k
# 6_features.1.BatchNorm2d_1             [51]  [1, 51, 41, 111]    102.0
# 7_features.1.Dropout2d_2                  -  [1, 51, 41, 111]        -
# 8_features.1.ReLU6_3                      -  [1, 51, 41, 111]        -
# 9_features.1.MaxPool2d_4                  -   [1, 51, 20, 55]        -
# 10_features.2.Conv2d_0       [51, 51, 3, 3]   [1, 51, 20, 55]   23.46k
# 11_features.2.BatchNorm2d_1            [51]   [1, 51, 20, 55]    102.0
# 12_features.2.Dropout2d_2                 -   [1, 51, 20, 55]        -
# 13_features.2.ReLU6_3                     -   [1, 51, 20, 55]        -
# 14_features.2.MaxPool2d_4                 -   [1, 51, 10, 27]        -
# 15_features.3.Conv2d_0       [51, 51, 3, 3]   [1, 51, 10, 27]   23.46k
# 16_features.3.BatchNorm2d_1            [51]   [1, 51, 10, 27]    102.0
# 17_features.3.Dropout2d_2                 -   [1, 51, 10, 27]        -
# 18_features.3.ReLU6_3                     -   [1, 51, 10, 27]        -
# 19_features.3.MaxPool2d_4                 -    [1, 51, 5, 13]        -
# 20_classifier.Flatten_0                   -         [1, 3315]        -
# 21_classifier.Dropout_1                   -         [1, 3315]        -
# 22_classifier.Linear_2           [3315, 10]           [1, 10]   33.16k
#
#                               Mult-Adds
# Layer
# 0_features.0.Conv2d_0           4.0959M
# 1_features.0.BatchNorm2d_1         25.0
# 2_features.0.Dropout2d_2              -
# 3_features.0.ReLU6_3                  -
# 4_features.0.MaxPool2d_4              -
# 5_features.1.Conv2d_0        52.222725M
# 6_features.1.BatchNorm2d_1         51.0
# 7_features.1.Dropout2d_2              -
# 8_features.1.ReLU6_3                  -
# 9_features.1.MaxPool2d_4              -
# 10_features.2.Conv2d_0         25.7499M
# 11_features.2.BatchNorm2d_1        51.0
# 12_features.2.Dropout2d_2             -
# 13_features.2.ReLU6_3                 -
# 14_features.2.MaxPool2d_4             -
# 15_features.3.Conv2d_0         6.32043M
# 16_features.3.BatchNorm2d_1        51.0
# 17_features.3.Dropout2d_2             -
# 18_features.3.ReLU6_3                 -
# 19_features.3.MaxPool2d_4             -
# 20_classifier.Flatten_0               -
# 21_classifier.Dropout_1               -
# 22_classifier.Linear_2           33.15k
# ----------------------------------------------------------------------------------
#                           Totals
# Total params             92.212k
# Trainable params         92.212k
# Non-trainable params         0.0
# Mult-Adds             88.422283M
# ==================================================================================
# new scaled resolution:  (68, 185)
# new feature extraction function generation: hop_length = 476
# new conv layers:
# inputs:  [1, 30, 61, 61]
# ouputs:  [30, 61, 61, 61]
# new dense layers:
# inputs:  [2684]
# ouputs:  [10]
# ==================================================================================
#                                Kernel Shape      Output Shape   Params  \
# Layer
# 0_features.0.Conv2d_0         [1, 30, 3, 3]  [1, 30, 68, 185]    300.0
# 1_features.0.BatchNorm2d_1             [30]  [1, 30, 68, 185]     60.0
# 2_features.0.Dropout2d_2                  -  [1, 30, 68, 185]        -
# 3_features.0.ReLU6_3                      -  [1, 30, 68, 185]        -
# 4_features.0.MaxPool2d_4                  -   [1, 30, 34, 92]        -
# 5_features.1.Conv2d_0        [30, 61, 3, 3]   [1, 61, 34, 92]  16.531k
# 6_features.1.BatchNorm2d_1             [61]   [1, 61, 34, 92]    122.0
# 7_features.1.Dropout2d_2                  -   [1, 61, 34, 92]        -
# 8_features.1.ReLU6_3                      -   [1, 61, 34, 92]        -
# 9_features.1.MaxPool2d_4                  -   [1, 61, 17, 46]        -
# 10_features.2.Conv2d_0       [61, 61, 3, 3]   [1, 61, 17, 46]   33.55k
# 11_features.2.BatchNorm2d_1            [61]   [1, 61, 17, 46]    122.0
# 12_features.2.Dropout2d_2                 -   [1, 61, 17, 46]        -
# 13_features.2.ReLU6_3                     -   [1, 61, 17, 46]        -
# 14_features.2.MaxPool2d_4                 -    [1, 61, 8, 23]        -
# 15_features.3.Conv2d_0       [61, 61, 3, 3]    [1, 61, 8, 23]   33.55k
# 16_features.3.BatchNorm2d_1            [61]    [1, 61, 8, 23]    122.0
# 17_features.3.Dropout2d_2                 -    [1, 61, 8, 23]        -
# 18_features.3.ReLU6_3                     -    [1, 61, 8, 23]        -
# 19_features.3.MaxPool2d_4                 -    [1, 61, 4, 11]        -
# 20_classifier.Flatten_0                   -         [1, 2684]        -
# 21_classifier.Dropout_1                   -         [1, 2684]        -
# 22_classifier.Linear_2           [2684, 10]           [1, 10]   26.85k
#
#                               Mult-Adds
# Layer
# 0_features.0.Conv2d_0           3.3966M
# 1_features.0.BatchNorm2d_1         30.0
# 2_features.0.Dropout2d_2              -
# 3_features.0.ReLU6_3                  -
# 4_features.0.MaxPool2d_4              -
# 5_features.1.Conv2d_0         51.51816M
# 6_features.1.BatchNorm2d_1         61.0
# 7_features.1.Dropout2d_2              -
# 8_features.1.ReLU6_3                  -
# 9_features.1.MaxPool2d_4              -
# 10_features.2.Conv2d_0       26.188398M
# 11_features.2.BatchNorm2d_1        61.0
# 12_features.2.Dropout2d_2             -
# 13_features.2.ReLU6_3                 -
# 14_features.2.MaxPool2d_4             -
# 15_features.3.Conv2d_0        6.161976M
# 16_features.3.BatchNorm2d_1        61.0
# 17_features.3.Dropout2d_2             -
# 18_features.3.ReLU6_3                 -
# 19_features.3.MaxPool2d_4             -
# 20_classifier.Flatten_0               -
# 21_classifier.Dropout_1               -
# 22_classifier.Linear_2           26.84k
# ----------------------------------------------------------------------------------
#                           Totals
# Total params            111.207k
# Trainable params        111.207k
# Non-trainable params         0.0
# Mult-Adds             87.292187M
# ==================================================================================
# new scaled resolution:  (64, 173)
# new feature extraction function generation: hop_length = 509
# new conv layers:
# inputs:  [1, 32, 65, 65]
# ouputs:  [32, 65, 65, 65]
# new dense layers:
# inputs:  [2600]
# ouputs:  [10]
# ==================================================================================
#                                Kernel Shape      Output Shape   Params  \
# Layer
# 0_features.0.Conv2d_0         [1, 32, 3, 3]  [1, 32, 64, 173]    320.0
# 1_features.0.BatchNorm2d_1             [32]  [1, 32, 64, 173]     64.0
# 2_features.0.Dropout2d_2                  -  [1, 32, 64, 173]        -
# 3_features.0.ReLU6_3                      -  [1, 32, 64, 173]        -
# 4_features.0.MaxPool2d_4                  -   [1, 32, 32, 86]        -
# 5_features.1.Conv2d_0        [32, 65, 3, 3]   [1, 65, 32, 86]  18.785k
# 6_features.1.BatchNorm2d_1             [65]   [1, 65, 32, 86]    130.0
# 7_features.1.Dropout2d_2                  -   [1, 65, 32, 86]        -
# 8_features.1.ReLU6_3                      -   [1, 65, 32, 86]        -
# 9_features.1.MaxPool2d_4                  -   [1, 65, 16, 43]        -
# 10_features.2.Conv2d_0       [65, 65, 3, 3]   [1, 65, 16, 43]   38.09k
# 11_features.2.BatchNorm2d_1            [65]   [1, 65, 16, 43]    130.0
# 12_features.2.Dropout2d_2                 -   [1, 65, 16, 43]        -
# 13_features.2.ReLU6_3                     -   [1, 65, 16, 43]        -
# 14_features.2.MaxPool2d_4                 -    [1, 65, 8, 21]        -
# 15_features.3.Conv2d_0       [65, 65, 3, 3]    [1, 65, 8, 21]   38.09k
# 16_features.3.BatchNorm2d_1            [65]    [1, 65, 8, 21]    130.0
# 17_features.3.Dropout2d_2                 -    [1, 65, 8, 21]        -
# 18_features.3.ReLU6_3                     -    [1, 65, 8, 21]        -
# 19_features.3.MaxPool2d_4                 -    [1, 65, 4, 10]        -
# 20_classifier.Flatten_0                   -         [1, 2600]        -
# 21_classifier.Dropout_1                   -         [1, 2600]        -
# 22_classifier.Linear_2           [2600, 10]           [1, 10]   26.01k
#
#                              Mult-Adds
# Layer
# 0_features.0.Conv2d_0        3.188736M
# 1_features.0.BatchNorm2d_1        32.0
# 2_features.0.Dropout2d_2             -
# 3_features.0.ReLU6_3                 -
# 4_features.0.MaxPool2d_4             -
# 5_features.1.Conv2d_0        51.51744M
# 6_features.1.BatchNorm2d_1        65.0
# 7_features.1.Dropout2d_2             -
# 8_features.1.ReLU6_3                 -
# 9_features.1.MaxPool2d_4             -
# 10_features.2.Conv2d_0        26.1612M
# 11_features.2.BatchNorm2d_1       65.0
# 12_features.2.Dropout2d_2            -
# 13_features.2.ReLU6_3                -
# 14_features.2.MaxPool2d_4            -
# 15_features.3.Conv2d_0         6.3882M
# 16_features.3.BatchNorm2d_1       65.0
# 17_features.3.Dropout2d_2            -
# 18_features.3.ReLU6_3                -
# 19_features.3.MaxPool2d_4            -
# 20_classifier.Flatten_0              -
# 21_classifier.Dropout_1              -
# 22_classifier.Linear_2           26.0k
# ----------------------------------------------------------------------------------
#                           Totals
# Total params            121.749k
# Trainable params        121.749k
# Non-trainable params         0.0
# Mult-Adds             87.281803M
# ==================================================================================
# new scaled resolution:  (82, 222)
# new feature extraction function generation: hop_length = 397
# new conv layers:
# inputs:  [1, 24, 48, 48]
# ouputs:  [24, 48, 48, 48]
# new dense layers:
# inputs:  [3120]
# ouputs:  [10]
# ==================================================================================
#                                Kernel Shape      Output Shape   Params  \
# Layer
# 0_features.0.Conv2d_0         [1, 24, 3, 3]  [1, 24, 82, 222]    240.0
# 1_features.0.BatchNorm2d_1             [24]  [1, 24, 82, 222]     48.0
# 2_features.0.Dropout2d_2                  -  [1, 24, 82, 222]        -
# 3_features.0.ReLU6_3                      -  [1, 24, 82, 222]        -
# 4_features.0.MaxPool2d_4                  -  [1, 24, 41, 111]        -
# 5_features.1.Conv2d_0        [24, 48, 3, 3]  [1, 48, 41, 111]  10.416k
# 6_features.1.BatchNorm2d_1             [48]  [1, 48, 41, 111]     96.0
# 7_features.1.Dropout2d_2                  -  [1, 48, 41, 111]        -
# 8_features.1.ReLU6_3                      -  [1, 48, 41, 111]        -
# 9_features.1.MaxPool2d_4                  -   [1, 48, 20, 55]        -
# 10_features.2.Conv2d_0       [48, 48, 3, 3]   [1, 48, 20, 55]  20.784k
# 11_features.2.BatchNorm2d_1            [48]   [1, 48, 20, 55]     96.0
# 12_features.2.Dropout2d_2                 -   [1, 48, 20, 55]        -
# 13_features.2.ReLU6_3                     -   [1, 48, 20, 55]        -
# 14_features.2.MaxPool2d_4                 -   [1, 48, 10, 27]        -
# 15_features.3.Conv2d_0       [48, 48, 3, 3]   [1, 48, 10, 27]  20.784k
# 16_features.3.BatchNorm2d_1            [48]   [1, 48, 10, 27]     96.0
# 17_features.3.Dropout2d_2                 -   [1, 48, 10, 27]        -
# 18_features.3.ReLU6_3                     -   [1, 48, 10, 27]        -
# 19_features.3.MaxPool2d_4                 -    [1, 48, 5, 13]        -
# 20_classifier.Flatten_0                   -         [1, 3120]        -
# 21_classifier.Dropout_1                   -         [1, 3120]        -
# 22_classifier.Linear_2           [3120, 10]           [1, 10]   31.21k
#
#                               Mult-Adds
# Layer
# 0_features.0.Conv2d_0         3.932064M
# 1_features.0.BatchNorm2d_1         24.0
# 2_features.0.Dropout2d_2              -
# 3_features.0.ReLU6_3                  -
# 4_features.0.MaxPool2d_4              -
# 5_features.1.Conv2d_0        47.184768M
# 6_features.1.BatchNorm2d_1         48.0
# 7_features.1.Dropout2d_2              -
# 8_features.1.ReLU6_3                  -
# 9_features.1.MaxPool2d_4              -
# 10_features.2.Conv2d_0         22.8096M
# 11_features.2.BatchNorm2d_1        48.0
# 12_features.2.Dropout2d_2             -
# 13_features.2.ReLU6_3                 -
# 14_features.2.MaxPool2d_4             -
# 15_features.3.Conv2d_0         5.59872M
# 16_features.3.BatchNorm2d_1        48.0
# 17_features.3.Dropout2d_2             -
# 18_features.3.ReLU6_3                 -
# 19_features.3.MaxPool2d_4             -
# 20_classifier.Flatten_0               -
# 21_classifier.Dropout_1               -
# 22_classifier.Linear_2            31.2k
# ----------------------------------------------------------------------------------
#                          Totals
# Total params             83.77k
# Trainable params         83.77k
# Non-trainable params        0.0
# Mult-Adds             79.55652M
# ==================================================================================
# new scaled resolution:  (64, 173)
# new feature extraction function generation: hop_length = 509
# new conv layers:
# inputs:  [1, 30, 61, 61]
# ouputs:  [30, 61, 61, 61]
# new dense layers:
# inputs:  [2440]
# ouputs:  [10]
# ==================================================================================
#                                Kernel Shape      Output Shape   Params  \
# Layer
# 0_features.0.Conv2d_0         [1, 30, 3, 3]  [1, 30, 64, 173]    300.0
# 1_features.0.BatchNorm2d_1             [30]  [1, 30, 64, 173]     60.0
# 2_features.0.Dropout2d_2                  -  [1, 30, 64, 173]        -
# 3_features.0.ReLU6_3                      -  [1, 30, 64, 173]        -
# 4_features.0.MaxPool2d_4                  -   [1, 30, 32, 86]        -
# 5_features.1.Conv2d_0        [30, 61, 3, 3]   [1, 61, 32, 86]  16.531k
# 6_features.1.BatchNorm2d_1             [61]   [1, 61, 32, 86]    122.0
# 7_features.1.Dropout2d_2                  -   [1, 61, 32, 86]        -
# 8_features.1.ReLU6_3                      -   [1, 61, 32, 86]        -
# 9_features.1.MaxPool2d_4                  -   [1, 61, 16, 43]        -
# 10_features.2.Conv2d_0       [61, 61, 3, 3]   [1, 61, 16, 43]   33.55k
# 11_features.2.BatchNorm2d_1            [61]   [1, 61, 16, 43]    122.0
# 12_features.2.Dropout2d_2                 -   [1, 61, 16, 43]        -
# 13_features.2.ReLU6_3                     -   [1, 61, 16, 43]        -
# 14_features.2.MaxPool2d_4                 -    [1, 61, 8, 21]        -
# 15_features.3.Conv2d_0       [61, 61, 3, 3]    [1, 61, 8, 21]   33.55k
# 16_features.3.BatchNorm2d_1            [61]    [1, 61, 8, 21]    122.0
# 17_features.3.Dropout2d_2                 -    [1, 61, 8, 21]        -
# 18_features.3.ReLU6_3                     -    [1, 61, 8, 21]        -
# 19_features.3.MaxPool2d_4                 -    [1, 61, 4, 10]        -
# 20_classifier.Flatten_0                   -         [1, 2440]        -
# 21_classifier.Dropout_1                   -         [1, 2440]        -
# 22_classifier.Linear_2           [2440, 10]           [1, 10]   24.41k
#
#                               Mult-Adds
# Layer
# 0_features.0.Conv2d_0          2.98944M
# 1_features.0.BatchNorm2d_1         30.0
# 2_features.0.Dropout2d_2              -
# 3_features.0.ReLU6_3                  -
# 4_features.0.MaxPool2d_4              -
# 5_features.1.Conv2d_0         45.32544M
# 6_features.1.BatchNorm2d_1         61.0
# 7_features.1.Dropout2d_2              -
# 8_features.1.ReLU6_3                  -
# 9_features.1.MaxPool2d_4              -
# 10_features.2.Conv2d_0       23.040432M
# 11_features.2.BatchNorm2d_1        61.0
# 12_features.2.Dropout2d_2             -
# 13_features.2.ReLU6_3                 -
# 14_features.2.MaxPool2d_4             -
# 15_features.3.Conv2d_0        5.626152M
# 16_features.3.BatchNorm2d_1        61.0
# 17_features.3.Dropout2d_2             -
# 18_features.3.ReLU6_3                 -
# 19_features.3.MaxPool2d_4             -
# 20_classifier.Flatten_0               -
# 21_classifier.Dropout_1               -
# 22_classifier.Linear_2            24.4k
# ----------------------------------------------------------------------------------
#                           Totals
# Total params            108.767k
# Trainable params        108.767k
# Non-trainable params         0.0
# Mult-Adds             77.006077M
# ==================================================================================
# new scaled resolution:  (77, 210)
# new feature extraction function generation: hop_length = 420
# More conv layer must be created
# new conv layers:
# inputs:  [1, 24, 48, 48, 48]
# ouputs:  [24, 48, 48, 48, 59]
# new dense layers:
# inputs:  [708]
# ouputs:  [10]
# ==================================================================================
#                                Kernel Shape      Output Shape   Params  \
# Layer
# 0_features.0.Conv2d_0         [1, 24, 3, 3]  [1, 24, 77, 210]    240.0
# 1_features.0.BatchNorm2d_1             [24]  [1, 24, 77, 210]     48.0
# 2_features.0.Dropout2d_2                  -  [1, 24, 77, 210]        -
# 3_features.0.ReLU6_3                      -  [1, 24, 77, 210]        -
# 4_features.0.MaxPool2d_4                  -  [1, 24, 38, 105]        -
# 5_features.1.Conv2d_0        [24, 48, 3, 3]  [1, 48, 38, 105]  10.416k
# 6_features.1.BatchNorm2d_1             [48]  [1, 48, 38, 105]     96.0
# 7_features.1.Dropout2d_2                  -  [1, 48, 38, 105]        -
# 8_features.1.ReLU6_3                      -  [1, 48, 38, 105]        -
# 9_features.1.MaxPool2d_4                  -   [1, 48, 19, 52]        -
# 10_features.2.Conv2d_0       [48, 48, 3, 3]   [1, 48, 19, 52]  20.784k
# 11_features.2.BatchNorm2d_1            [48]   [1, 48, 19, 52]     96.0
# 12_features.2.Dropout2d_2                 -   [1, 48, 19, 52]        -
# 13_features.2.ReLU6_3                     -   [1, 48, 19, 52]        -
# 14_features.2.MaxPool2d_4                 -    [1, 48, 9, 26]        -
# 15_features.3.Conv2d_0       [48, 48, 3, 3]    [1, 48, 9, 26]  20.784k
# 16_features.3.BatchNorm2d_1            [48]    [1, 48, 9, 26]     96.0
# 17_features.3.Dropout2d_2                 -    [1, 48, 9, 26]        -
# 18_features.3.ReLU6_3                     -    [1, 48, 9, 26]        -
# 19_features.3.MaxPool2d_4                 -    [1, 48, 4, 13]        -
# 20_features.4.Conv2d_0       [48, 59, 3, 3]    [1, 59, 4, 13]  25.547k
# 21_features.4.BatchNorm2d_1            [59]    [1, 59, 4, 13]    118.0
# 22_features.4.Dropout2d_2                 -    [1, 59, 4, 13]        -
# 23_features.4.ReLU6_3                     -    [1, 59, 4, 13]        -
# 24_features.4.MaxPool2d_4                 -     [1, 59, 2, 6]        -
# 25_classifier.Flatten_0                   -          [1, 708]        -
# 26_classifier.Dropout_1                   -          [1, 708]        -
# 27_classifier.Linear_2            [708, 10]           [1, 10]    7.09k
#
#                               Mult-Adds
# Layer
# 0_features.0.Conv2d_0          3.49272M
# 1_features.0.BatchNorm2d_1         24.0
# 2_features.0.Dropout2d_2              -
# 3_features.0.ReLU6_3                  -
# 4_features.0.MaxPool2d_4              -
# 5_features.1.Conv2d_0         41.36832M
# 6_features.1.BatchNorm2d_1         48.0
# 7_features.1.Dropout2d_2              -
# 8_features.1.ReLU6_3                  -
# 9_features.1.MaxPool2d_4              -
# 10_features.2.Conv2d_0       20.487168M
# 11_features.2.BatchNorm2d_1        48.0
# 12_features.2.Dropout2d_2             -
# 13_features.2.ReLU6_3                 -
# 14_features.2.MaxPool2d_4             -
# 15_features.3.Conv2d_0        4.852224M
# 16_features.3.BatchNorm2d_1        48.0
# 17_features.3.Dropout2d_2             -
# 18_features.3.ReLU6_3                 -
# 19_features.3.MaxPool2d_4             -
# 20_features.4.Conv2d_0        1.325376M
# 21_features.4.BatchNorm2d_1        59.0
# 22_features.4.Dropout2d_2             -
# 23_features.4.ReLU6_3                 -
# 24_features.4.MaxPool2d_4             -
# 25_classifier.Flatten_0               -
# 26_classifier.Dropout_1               -
# 27_classifier.Linear_2            7.08k
# ----------------------------------------------------------------------------------
#                           Totals
# Total params             85.315k
# Trainable params         85.315k
# Non-trainable params         0.0
# Mult-Adds             71.533115M
# ==================================================================================
# new scaled resolution:  (73, 197)
# new feature extraction function generation: hop_length = 447
# More conv layer must be created
# new conv layers:
# inputs:  [1, 25, 51, 51, 51]
# ouputs:  [25, 51, 51, 51, 63]
# new dense layers:
# inputs:  [756]
# ouputs:  [10]
# ==================================================================================
#                                Kernel Shape      Output Shape   Params  \
# Layer
# 0_features.0.Conv2d_0         [1, 25, 3, 3]  [1, 25, 73, 197]    250.0
# 1_features.0.BatchNorm2d_1             [25]  [1, 25, 73, 197]     50.0
# 2_features.0.Dropout2d_2                  -  [1, 25, 73, 197]        -
# 3_features.0.ReLU6_3                      -  [1, 25, 73, 197]        -
# 4_features.0.MaxPool2d_4                  -   [1, 25, 36, 98]        -
# 5_features.1.Conv2d_0        [25, 51, 3, 3]   [1, 51, 36, 98]  11.526k
# 6_features.1.BatchNorm2d_1             [51]   [1, 51, 36, 98]    102.0
# 7_features.1.Dropout2d_2                  -   [1, 51, 36, 98]        -
# 8_features.1.ReLU6_3                      -   [1, 51, 36, 98]        -
# 9_features.1.MaxPool2d_4                  -   [1, 51, 18, 49]        -
# 10_features.2.Conv2d_0       [51, 51, 3, 3]   [1, 51, 18, 49]   23.46k
# 11_features.2.BatchNorm2d_1            [51]   [1, 51, 18, 49]    102.0
# 12_features.2.Dropout2d_2                 -   [1, 51, 18, 49]        -
# 13_features.2.ReLU6_3                     -   [1, 51, 18, 49]        -
# 14_features.2.MaxPool2d_4                 -    [1, 51, 9, 24]        -
# 15_features.3.Conv2d_0       [51, 51, 3, 3]    [1, 51, 9, 24]   23.46k
# 16_features.3.BatchNorm2d_1            [51]    [1, 51, 9, 24]    102.0
# 17_features.3.Dropout2d_2                 -    [1, 51, 9, 24]        -
# 18_features.3.ReLU6_3                     -    [1, 51, 9, 24]        -
# 19_features.3.MaxPool2d_4                 -    [1, 51, 4, 12]        -
# 20_features.4.Conv2d_0       [51, 63, 3, 3]    [1, 63, 4, 12]   28.98k
# 21_features.4.BatchNorm2d_1            [63]    [1, 63, 4, 12]    126.0
# 22_features.4.Dropout2d_2                 -    [1, 63, 4, 12]        -
# 23_features.4.ReLU6_3                     -    [1, 63, 4, 12]        -
# 24_features.4.MaxPool2d_4                 -     [1, 63, 2, 6]        -
# 25_classifier.Flatten_0                   -          [1, 756]        -
# 26_classifier.Dropout_1                   -          [1, 756]        -
# 27_classifier.Linear_2            [756, 10]           [1, 10]    7.57k
#
#                               Mult-Adds
# Layer
# 0_features.0.Conv2d_0         3.235725M
# 1_features.0.BatchNorm2d_1         25.0
# 2_features.0.Dropout2d_2              -
# 3_features.0.ReLU6_3                  -
# 4_features.0.MaxPool2d_4              -
# 5_features.1.Conv2d_0          40.4838M
# 6_features.1.BatchNorm2d_1         51.0
# 7_features.1.Dropout2d_2              -
# 8_features.1.ReLU6_3                  -
# 9_features.1.MaxPool2d_4              -
# 10_features.2.Conv2d_0       20.646738M
# 11_features.2.BatchNorm2d_1        51.0
# 12_features.2.Dropout2d_2             -
# 13_features.2.ReLU6_3                 -
# 14_features.2.MaxPool2d_4             -
# 15_features.3.Conv2d_0        5.056344M
# 16_features.3.BatchNorm2d_1        51.0
# 17_features.3.Dropout2d_2             -
# 18_features.3.ReLU6_3                 -
# 19_features.3.MaxPool2d_4             -
# 20_features.4.Conv2d_0        1.388016M
# 21_features.4.BatchNorm2d_1        63.0
# 22_features.4.Dropout2d_2             -
# 23_features.4.ReLU6_3                 -
# 24_features.4.MaxPool2d_4             -
# 25_classifier.Flatten_0               -
# 26_classifier.Dropout_1               -
# 27_classifier.Linear_2            7.56k
# ----------------------------------------------------------------------------------
#                           Totals
# Total params             95.728k
# Trainable params         95.728k
# Non-trainable params         0.0
# Mult-Adds             70.818424M
# ==================================================================================
# new scaled resolution:  (68, 185)
# new feature extraction function generation: hop_length = 476
# More conv layer must be created
# new conv layers:
# inputs:  [1, 27, 54, 54, 54]
# ouputs:  [27, 54, 54, 54, 67]
# new dense layers:
# inputs:  [670]
# ouputs:  [10]
# ==================================================================================
#                                Kernel Shape      Output Shape   Params  \
# Layer
# 0_features.0.Conv2d_0         [1, 27, 3, 3]  [1, 27, 68, 185]    270.0
# 1_features.0.BatchNorm2d_1             [27]  [1, 27, 68, 185]     54.0
# 2_features.0.Dropout2d_2                  -  [1, 27, 68, 185]        -
# 3_features.0.ReLU6_3                      -  [1, 27, 68, 185]        -
# 4_features.0.MaxPool2d_4                  -   [1, 27, 34, 92]        -
# 5_features.1.Conv2d_0        [27, 54, 3, 3]   [1, 54, 34, 92]  13.176k
# 6_features.1.BatchNorm2d_1             [54]   [1, 54, 34, 92]    108.0
# 7_features.1.Dropout2d_2                  -   [1, 54, 34, 92]        -
# 8_features.1.ReLU6_3                      -   [1, 54, 34, 92]        -
# 9_features.1.MaxPool2d_4                  -   [1, 54, 17, 46]        -
# 10_features.2.Conv2d_0       [54, 54, 3, 3]   [1, 54, 17, 46]  26.298k
# 11_features.2.BatchNorm2d_1            [54]   [1, 54, 17, 46]    108.0
# 12_features.2.Dropout2d_2                 -   [1, 54, 17, 46]        -
# 13_features.2.ReLU6_3                     -   [1, 54, 17, 46]        -
# 14_features.2.MaxPool2d_4                 -    [1, 54, 8, 23]        -
# 15_features.3.Conv2d_0       [54, 54, 3, 3]    [1, 54, 8, 23]  26.298k
# 16_features.3.BatchNorm2d_1            [54]    [1, 54, 8, 23]    108.0
# 17_features.3.Dropout2d_2                 -    [1, 54, 8, 23]        -
# 18_features.3.ReLU6_3                     -    [1, 54, 8, 23]        -
# 19_features.3.MaxPool2d_4                 -    [1, 54, 4, 11]        -
# 20_features.4.Conv2d_0       [54, 67, 3, 3]    [1, 67, 4, 11]  32.629k
# 21_features.4.BatchNorm2d_1            [67]    [1, 67, 4, 11]    134.0
# 22_features.4.Dropout2d_2                 -    [1, 67, 4, 11]        -
# 23_features.4.ReLU6_3                     -    [1, 67, 4, 11]        -
# 24_features.4.MaxPool2d_4                 -     [1, 67, 2, 5]        -
# 25_classifier.Flatten_0                   -          [1, 670]        -
# 26_classifier.Dropout_1                   -          [1, 670]        -
# 27_classifier.Linear_2            [670, 10]           [1, 10]    6.71k
#
#                               Mult-Adds
# Layer
# 0_features.0.Conv2d_0          3.05694M
# 1_features.0.BatchNorm2d_1         27.0
# 2_features.0.Dropout2d_2              -
# 3_features.0.ReLU6_3                  -
# 4_features.0.MaxPool2d_4              -
# 5_features.1.Conv2d_0        41.045616M
# 6_features.1.BatchNorm2d_1         54.0
# 7_features.1.Dropout2d_2              -
# 8_features.1.ReLU6_3                  -
# 9_features.1.MaxPool2d_4              -
# 10_features.2.Conv2d_0       20.522808M
# 11_features.2.BatchNorm2d_1        54.0
# 12_features.2.Dropout2d_2             -
# 13_features.2.ReLU6_3                 -
# 14_features.2.MaxPool2d_4             -
# 15_features.3.Conv2d_0        4.828896M
# 16_features.3.BatchNorm2d_1        54.0
# 17_features.3.Dropout2d_2             -
# 18_features.3.ReLU6_3                 -
# 19_features.3.MaxPool2d_4             -
# 20_features.4.Conv2d_0        1.432728M
# 21_features.4.BatchNorm2d_1        67.0
# 22_features.4.Dropout2d_2             -
# 23_features.4.ReLU6_3                 -
# 24_features.4.MaxPool2d_4             -
# 25_classifier.Flatten_0               -
# 26_classifier.Dropout_1               -
# 27_classifier.Linear_2             6.7k
# ----------------------------------------------------------------------------------
#                           Totals
# Total params            105.893k
# Trainable params        105.893k
# Non-trainable params         0.0
# Mult-Adds             70.893944M
# ==================================================================================
# new scaled resolution:  (64, 173)
# new feature extraction function generation: hop_length = 509
# More conv layer must be created
# new conv layers:
# inputs:  [1, 29, 58, 58, 58]
# ouputs:  [29, 58, 58, 58, 71]
# new dense layers:
# inputs:  [710]
# ouputs:  [10]
# ==================================================================================
#                                Kernel Shape      Output Shape   Params  \
# Layer
# 0_features.0.Conv2d_0         [1, 29, 3, 3]  [1, 29, 64, 173]    290.0
# 1_features.0.BatchNorm2d_1             [29]  [1, 29, 64, 173]     58.0
# 2_features.0.Dropout2d_2                  -  [1, 29, 64, 173]        -
# 3_features.0.ReLU6_3                      -  [1, 29, 64, 173]        -
# 4_features.0.MaxPool2d_4                  -   [1, 29, 32, 86]        -
# 5_features.1.Conv2d_0        [29, 58, 3, 3]   [1, 58, 32, 86]  15.196k
# 6_features.1.BatchNorm2d_1             [58]   [1, 58, 32, 86]    116.0
# 7_features.1.Dropout2d_2                  -   [1, 58, 32, 86]        -
# 8_features.1.ReLU6_3                      -   [1, 58, 32, 86]        -
# 9_features.1.MaxPool2d_4                  -   [1, 58, 16, 43]        -
# 10_features.2.Conv2d_0       [58, 58, 3, 3]   [1, 58, 16, 43]  30.334k
# 11_features.2.BatchNorm2d_1            [58]   [1, 58, 16, 43]    116.0
# 12_features.2.Dropout2d_2                 -   [1, 58, 16, 43]        -
# 13_features.2.ReLU6_3                     -   [1, 58, 16, 43]        -
# 14_features.2.MaxPool2d_4                 -    [1, 58, 8, 21]        -
# 15_features.3.Conv2d_0       [58, 58, 3, 3]    [1, 58, 8, 21]  30.334k
# 16_features.3.BatchNorm2d_1            [58]    [1, 58, 8, 21]    116.0
# 17_features.3.Dropout2d_2                 -    [1, 58, 8, 21]        -
# 18_features.3.ReLU6_3                     -    [1, 58, 8, 21]        -
# 19_features.3.MaxPool2d_4                 -    [1, 58, 4, 10]        -
# 20_features.4.Conv2d_0       [58, 71, 3, 3]    [1, 71, 4, 10]  37.133k
# 21_features.4.BatchNorm2d_1            [71]    [1, 71, 4, 10]    142.0
# 22_features.4.Dropout2d_2                 -    [1, 71, 4, 10]        -
# 23_features.4.ReLU6_3                     -    [1, 71, 4, 10]        -
# 24_features.4.MaxPool2d_4                 -     [1, 71, 2, 5]        -
# 25_classifier.Flatten_0                   -          [1, 710]        -
# 26_classifier.Dropout_1                   -          [1, 710]        -
# 27_classifier.Linear_2            [710, 10]           [1, 10]    7.11k
#
#                               Mult-Adds
# Layer
# 0_features.0.Conv2d_0         2.889792M
# 1_features.0.BatchNorm2d_1         29.0
# 2_features.0.Dropout2d_2              -
# 3_features.0.ReLU6_3                  -
# 4_features.0.MaxPool2d_4              -
# 5_features.1.Conv2d_0        41.659776M
# 6_features.1.BatchNorm2d_1         58.0
# 7_features.1.Dropout2d_2              -
# 8_features.1.ReLU6_3                  -
# 9_features.1.MaxPool2d_4              -
# 10_features.2.Conv2d_0       20.829888M
# 11_features.2.BatchNorm2d_1        58.0
# 12_features.2.Dropout2d_2             -
# 13_features.2.ReLU6_3                 -
# 14_features.2.MaxPool2d_4             -
# 15_features.3.Conv2d_0        5.086368M
# 16_features.3.BatchNorm2d_1        58.0
# 17_features.3.Dropout2d_2             -
# 18_features.3.ReLU6_3                 -
# 19_features.3.MaxPool2d_4             -
# 20_features.4.Conv2d_0         1.48248M
# 21_features.4.BatchNorm2d_1        71.0
# 22_features.4.Dropout2d_2             -
# 23_features.4.ReLU6_3                 -
# 24_features.4.MaxPool2d_4             -
# 25_classifier.Flatten_0               -
# 26_classifier.Dropout_1               -
# 27_classifier.Linear_2             7.1k
# ----------------------------------------------------------------------------------
#                           Totals
# Total params            120.945k
# Trainable params        120.945k
# Non-trainable params         0.0
# Mult-Adds             71.955678M
# ==================================================================================
# new scaled resolution:  (73, 197)
# new feature extraction function generation: hop_length = 447
# More conv layer must be created
# new conv layers:
# inputs:  [1, 24, 48, 48, 48, 59]
# ouputs:  [24, 48, 48, 48, 59, 70]
# new dense layers:
# inputs:  [210]
# ouputs:  [10]
# ==================================================================================
#                                Kernel Shape      Output Shape   Params  \
# Layer
# 0_features.0.Conv2d_0         [1, 24, 3, 3]  [1, 24, 73, 197]    240.0
# 1_features.0.BatchNorm2d_1             [24]  [1, 24, 73, 197]     48.0
# 2_features.0.Dropout2d_2                  -  [1, 24, 73, 197]        -
# 3_features.0.ReLU6_3                      -  [1, 24, 73, 197]        -
# 4_features.0.MaxPool2d_4                  -   [1, 24, 36, 98]        -
# 5_features.1.Conv2d_0        [24, 48, 3, 3]   [1, 48, 36, 98]  10.416k
# 6_features.1.BatchNorm2d_1             [48]   [1, 48, 36, 98]     96.0
# 7_features.1.Dropout2d_2                  -   [1, 48, 36, 98]        -
# 8_features.1.ReLU6_3                      -   [1, 48, 36, 98]        -
# 9_features.1.MaxPool2d_4                  -   [1, 48, 18, 49]        -
# 10_features.2.Conv2d_0       [48, 48, 3, 3]   [1, 48, 18, 49]  20.784k
# 11_features.2.BatchNorm2d_1            [48]   [1, 48, 18, 49]     96.0
# 12_features.2.Dropout2d_2                 -   [1, 48, 18, 49]        -
# 13_features.2.ReLU6_3                     -   [1, 48, 18, 49]        -
# 14_features.2.MaxPool2d_4                 -    [1, 48, 9, 24]        -
# 15_features.3.Conv2d_0       [48, 48, 3, 3]    [1, 48, 9, 24]  20.784k
# 16_features.3.BatchNorm2d_1            [48]    [1, 48, 9, 24]     96.0
# 17_features.3.Dropout2d_2                 -    [1, 48, 9, 24]        -
# 18_features.3.ReLU6_3                     -    [1, 48, 9, 24]        -
# 19_features.3.MaxPool2d_4                 -    [1, 48, 4, 12]        -
# 20_features.4.Conv2d_0       [48, 59, 3, 3]    [1, 59, 4, 12]  25.547k
# 21_features.4.BatchNorm2d_1            [59]    [1, 59, 4, 12]    118.0
# 22_features.4.Dropout2d_2                 -    [1, 59, 4, 12]        -
# 23_features.4.ReLU6_3                     -    [1, 59, 4, 12]        -
# 24_features.4.MaxPool2d_4                 -     [1, 59, 2, 6]        -
# 25_features.5.Conv2d_0       [59, 70, 3, 3]     [1, 70, 2, 6]   37.24k
# 26_features.5.BatchNorm2d_1            [70]     [1, 70, 2, 6]    140.0
# 27_features.5.Dropout2d_2                 -     [1, 70, 2, 6]        -
# 28_features.5.ReLU6_3                     -     [1, 70, 2, 6]        -
# 29_features.5.MaxPool2d_4                 -     [1, 70, 1, 3]        -
# 30_classifier.Flatten_0                   -          [1, 210]        -
# 31_classifier.Dropout_1                   -          [1, 210]        -
# 32_classifier.Linear_2            [210, 10]           [1, 10]    2.11k
#
#                               Mult-Adds
# Layer
# 0_features.0.Conv2d_0         3.106296M
# 1_features.0.BatchNorm2d_1         24.0
# 2_features.0.Dropout2d_2              -
# 3_features.0.ReLU6_3                  -
# 4_features.0.MaxPool2d_4              -
# ...
# 28_features.5.ReLU6_3                 -
# 29_features.5.MaxPool2d_4             -
# 30_classifier.Flatten_0               -
# 31_classifier.Dropout_1               -
# 32_classifier.Linear_2             1.5k
# ----------------------------------------------------------------------------------
#                          Totals
# Total params           132.418k
# Trainable params       132.418k
# Non-trainable params        0.0
# Mult-Adds             55.69225M
# ==================================================================================
# new scaled resolution:  (68, 185)
# new feature extraction function generation: hop_length = 476
# More conv layer must be created
# new conv layers:
# inputs:  [1, 24, 48, 48, 48, 59, 70]
# ouputs:  [24, 48, 48, 48, 59, 70, 81]
# new dense layers:
# inputs:  [162]
# ouputs:  [10]
# ==================================================================================
#                                Kernel Shape      Output Shape   Params  \
# Layer
# 0_features.0.Conv2d_0         [1, 24, 3, 3]  [1, 24, 68, 185]    240.0
# 1_features.0.BatchNorm2d_1             [24]  [1, 24, 68, 185]     48.0
# 2_features.0.Dropout2d_2                  -  [1, 24, 68, 185]        -
# 3_features.0.ReLU6_3                      -  [1, 24, 68, 185]        -
# 4_features.0.MaxPool2d_4                  -   [1, 24, 34, 92]        -
# 5_features.1.Conv2d_0        [24, 48, 3, 3]   [1, 48, 34, 92]  10.416k
# 6_features.1.BatchNorm2d_1             [48]   [1, 48, 34, 92]     96.0
# 7_features.1.Dropout2d_2                  -   [1, 48, 34, 92]        -
# 8_features.1.ReLU6_3                      -   [1, 48, 34, 92]        -
# 9_features.1.MaxPool2d_4                  -   [1, 48, 17, 46]        -
# 10_features.2.Conv2d_0       [48, 48, 3, 3]   [1, 48, 17, 46]  20.784k
# 11_features.2.BatchNorm2d_1            [48]   [1, 48, 17, 46]     96.0
# 12_features.2.Dropout2d_2                 -   [1, 48, 17, 46]        -
# 13_features.2.ReLU6_3                     -   [1, 48, 17, 46]        -
# 14_features.2.MaxPool2d_4                 -    [1, 48, 8, 23]        -
# 15_features.3.Conv2d_0       [48, 48, 3, 3]    [1, 48, 8, 23]  20.784k
# 16_features.3.BatchNorm2d_1            [48]    [1, 48, 8, 23]     96.0
# 17_features.3.Dropout2d_2                 -    [1, 48, 8, 23]        -
# 18_features.3.ReLU6_3                     -    [1, 48, 8, 23]        -
# 19_features.3.MaxPool2d_4                 -    [1, 48, 4, 11]        -
# 20_features.4.Conv2d_0       [48, 59, 3, 3]    [1, 59, 4, 11]  25.547k
# 21_features.4.BatchNorm2d_1            [59]    [1, 59, 4, 11]    118.0
# 22_features.4.Dropout2d_2                 -    [1, 59, 4, 11]        -
# 23_features.4.ReLU6_3                     -    [1, 59, 4, 11]        -
# 24_features.4.MaxPool2d_4                 -     [1, 59, 2, 5]        -
# 25_features.5.Conv2d_0       [59, 70, 3, 3]     [1, 70, 2, 5]   37.24k
# 26_features.5.BatchNorm2d_1            [70]     [1, 70, 2, 5]    140.0
# 27_features.5.Dropout2d_2                 -     [1, 70, 2, 5]        -
# 28_features.5.ReLU6_3                     -     [1, 70, 2, 5]        -
# 29_features.5.MaxPool2d_4                 -     [1, 70, 1, 2]        -
# 30_features.6.Conv2d_0       [70, 81, 3, 3]     [1, 81, 1, 2]  51.111k
# 31_features.6.ReLU6_1                     -     [1, 81, 1, 2]        -
# 32_classifier.Flatten_0                   -          [1, 162]        -
# 33_classifier.Dropout_1                   -          [1, 162]        -
# 34_classifier.Linear_2            [162, 10]           [1, 10]    1.63k
#
#                               Mult-Adds
# Layer
# 0_features.0.Conv2d_0          2.71728M
# 1_features.0.BatchNorm2d_1         24.0
# 2_features.0.Dropout2d_2              -
# 3_features.0.ReLU6_3                  -
# 4_features.0.MaxPool2d_4              -
# 5_features.1.Conv2d_0        32.431104M
# 6_features.1.BatchNorm2d_1         48.0
# 7_features.1.Dropout2d_2              -
# 8_features.1.ReLU6_3                  -
# 9_features.1.MaxPool2d_4              -
# 10_features.2.Conv2d_0       16.215552M
# 11_features.2.BatchNorm2d_1        48.0
# 12_features.2.Dropout2d_2             -
# 13_features.2.ReLU6_3                 -
# 14_features.2.MaxPool2d_4             -
# 15_features.3.Conv2d_0        3.815424M
# 16_features.3.BatchNorm2d_1        48.0
# 17_features.3.Dropout2d_2             -
# 18_features.3.ReLU6_3                 -
# 19_features.3.MaxPool2d_4             -
# 20_features.4.Conv2d_0        1.121472M
# 21_features.4.BatchNorm2d_1        59.0
# 22_features.4.Dropout2d_2             -
# 23_features.4.ReLU6_3                 -
# 24_features.4.MaxPool2d_4             -
# 25_features.5.Conv2d_0           371.7k
# 26_features.5.BatchNorm2d_1        70.0
# 27_features.5.Dropout2d_2             -
# 28_features.5.ReLU6_3                 -
# 29_features.5.MaxPool2d_4             -
# 30_features.6.Conv2d_0          102.06k
# 31_features.6.ReLU6_1                 -
# 32_classifier.Flatten_0               -
# 33_classifier.Dropout_1               -
# 34_classifier.Linear_2            1.62k
# ----------------------------------------------------------------------------------
#                           Totals
# Total params            168.346k
# Trainable params        168.346k
# Non-trainable params         0.0
# Mult-Adds             56.776509M
# ==================================================================================
# new scaled resolution:  (64, 173)
# new feature extraction function generation: hop_length = 509
# More conv layer must be created
# new conv layers:
# inputs:  [1, 25, 51, 51, 51, 63, 75]
# ouputs:  [25, 51, 51, 51, 63, 75, 86]
# new dense layers:
# inputs:  [172]
# ouputs:  [10]
# ==================================================================================
#                                Kernel Shape      Output Shape   Params  \
# Layer
# 0_features.0.Conv2d_0         [1, 25, 3, 3]  [1, 25, 64, 173]    250.0
# 1_features.0.BatchNorm2d_1             [25]  [1, 25, 64, 173]     50.0
# 2_features.0.Dropout2d_2                  -  [1, 25, 64, 173]        -
# 3_features.0.ReLU6_3                      -  [1, 25, 64, 173]        -
# 4_features.0.MaxPool2d_4                  -   [1, 25, 32, 86]        -
# 5_features.1.Conv2d_0        [25, 51, 3, 3]   [1, 51, 32, 86]  11.526k
# 6_features.1.BatchNorm2d_1             [51]   [1, 51, 32, 86]    102.0
# 7_features.1.Dropout2d_2                  -   [1, 51, 32, 86]        -
# 8_features.1.ReLU6_3                      -   [1, 51, 32, 86]        -
# 9_features.1.MaxPool2d_4                  -   [1, 51, 16, 43]        -
# 10_features.2.Conv2d_0       [51, 51, 3, 3]   [1, 51, 16, 43]   23.46k
# 11_features.2.BatchNorm2d_1            [51]   [1, 51, 16, 43]    102.0
# 12_features.2.Dropout2d_2                 -   [1, 51, 16, 43]        -
# 13_features.2.ReLU6_3                     -   [1, 51, 16, 43]        -
# 14_features.2.MaxPool2d_4                 -    [1, 51, 8, 21]        -
# 15_features.3.Conv2d_0       [51, 51, 3, 3]    [1, 51, 8, 21]   23.46k
# 16_features.3.BatchNorm2d_1            [51]    [1, 51, 8, 21]    102.0
# 17_features.3.Dropout2d_2                 -    [1, 51, 8, 21]        -
# 18_features.3.ReLU6_3                     -    [1, 51, 8, 21]        -
# 19_features.3.MaxPool2d_4                 -    [1, 51, 4, 10]        -
# 20_features.4.Conv2d_0       [51, 63, 3, 3]    [1, 63, 4, 10]   28.98k
# 21_features.4.BatchNorm2d_1            [63]    [1, 63, 4, 10]    126.0
# 22_features.4.Dropout2d_2                 -    [1, 63, 4, 10]        -
# 23_features.4.ReLU6_3                     -    [1, 63, 4, 10]        -
# 24_features.4.MaxPool2d_4                 -     [1, 63, 2, 5]        -
# 25_features.5.Conv2d_0       [63, 75, 3, 3]     [1, 75, 2, 5]    42.6k
# 26_features.5.BatchNorm2d_1            [75]     [1, 75, 2, 5]    150.0
# 27_features.5.Dropout2d_2                 -     [1, 75, 2, 5]        -
# 28_features.5.ReLU6_3                     -     [1, 75, 2, 5]        -
# 29_features.5.MaxPool2d_4                 -     [1, 75, 1, 2]        -
# 30_features.6.Conv2d_0       [75, 86, 3, 3]     [1, 86, 1, 2]  58.136k
# 31_features.6.ReLU6_1                     -     [1, 86, 1, 2]        -
# 32_classifier.Flatten_0                   -          [1, 172]        -
# 33_classifier.Dropout_1                   -          [1, 172]        -
# 34_classifier.Linear_2            [172, 10]           [1, 10]    1.73k
#
#                               Mult-Adds
# Layer
# 0_features.0.Conv2d_0           2.4912M
# 1_features.0.BatchNorm2d_1         25.0
# 2_features.0.Dropout2d_2              -
# 3_features.0.ReLU6_3                  -
# 4_features.0.MaxPool2d_4              -
# 5_features.1.Conv2d_0          31.5792M
# 6_features.1.BatchNorm2d_1         51.0
# 7_features.1.Dropout2d_2              -
# 8_features.1.ReLU6_3                  -
# 9_features.1.MaxPool2d_4              -
# 10_features.2.Conv2d_0       16.105392M
# 11_features.2.BatchNorm2d_1        51.0
# 12_features.2.Dropout2d_2             -
# 13_features.2.ReLU6_3                 -
# 14_features.2.MaxPool2d_4             -
# 15_features.3.Conv2d_0        3.932712M
# 16_features.3.BatchNorm2d_1        51.0
# 17_features.3.Dropout2d_2             -
# 18_features.3.ReLU6_3                 -
# 19_features.3.MaxPool2d_4             -
# 20_features.4.Conv2d_0         1.15668M
# 21_features.4.BatchNorm2d_1        63.0
# 22_features.4.Dropout2d_2             -
# 23_features.4.ReLU6_3                 -
# 24_features.4.MaxPool2d_4             -
# 25_features.5.Conv2d_0          425.25k
# 26_features.5.BatchNorm2d_1        75.0
# 27_features.5.Dropout2d_2             -
# 28_features.5.ReLU6_3                 -
# 29_features.5.MaxPool2d_4             -
# 30_features.6.Conv2d_0           116.1k
# 31_features.6.ReLU6_1                 -
# 32_classifier.Flatten_0               -
# 33_classifier.Dropout_1               -
# 34_classifier.Linear_2            1.72k
# ----------------------------------------------------------------------------------
#                          Totals
# Total params           190.774k
# Trainable params       190.774k
# Non-trainable params        0.0
# Mult-Adds             55.80857M
# ==================================================================================
# new scaled resolution:  (64, 173)
# new feature extraction function generation: hop_length = 509
# More conv layer must be created
# new conv layers:
# inputs:  [1, 24, 48, 48, 48, 59, 70, 81]
# ouputs:  [24, 48, 48, 48, 59, 70, 81, 92]
# More dense layer must be created
# new dense layers:
# inputs:  [184, 97]
# ouputs:  [97, 10]
# 184 97
# ==================================================================================
#                                Kernel Shape      Output Shape   Params  \
# Layer
# 0_features.0.Conv2d_0         [1, 24, 3, 3]  [1, 24, 64, 173]    240.0
# 1_features.0.BatchNorm2d_1             [24]  [1, 24, 64, 173]     48.0
# 2_features.0.Dropout2d_2                  -  [1, 24, 64, 173]        -
# 3_features.0.ReLU6_3                      -  [1, 24, 64, 173]        -
# 4_features.0.MaxPool2d_4                  -   [1, 24, 32, 86]        -
# 5_features.1.Conv2d_0        [24, 48, 3, 3]   [1, 48, 32, 86]  10.416k
# 6_features.1.BatchNorm2d_1             [48]   [1, 48, 32, 86]     96.0
# 7_features.1.Dropout2d_2                  -   [1, 48, 32, 86]        -
# 8_features.1.ReLU6_3                      -   [1, 48, 32, 86]        -
# 9_features.1.MaxPool2d_4                  -   [1, 48, 16, 43]        -
# 10_features.2.Conv2d_0       [48, 48, 3, 3]   [1, 48, 16, 43]  20.784k
# 11_features.2.BatchNorm2d_1            [48]   [1, 48, 16, 43]     96.0
# 12_features.2.Dropout2d_2                 -   [1, 48, 16, 43]        -
# 13_features.2.ReLU6_3                     -   [1, 48, 16, 43]        -
# 14_features.2.MaxPool2d_4                 -    [1, 48, 8, 21]        -
# 15_features.3.Conv2d_0       [48, 48, 3, 3]    [1, 48, 8, 21]  20.784k
# 16_features.3.BatchNorm2d_1            [48]    [1, 48, 8, 21]     96.0
# 17_features.3.Dropout2d_2                 -    [1, 48, 8, 21]        -
# 18_features.3.ReLU6_3                     -    [1, 48, 8, 21]        -
# 19_features.3.MaxPool2d_4                 -    [1, 48, 4, 10]        -
# 20_features.4.Conv2d_0       [48, 59, 3, 3]    [1, 59, 4, 10]  25.547k
# 21_features.4.BatchNorm2d_1            [59]    [1, 59, 4, 10]    118.0
# 22_features.4.Dropout2d_2                 -    [1, 59, 4, 10]        -
# 23_features.4.ReLU6_3                     -    [1, 59, 4, 10]        -
# 24_features.4.MaxPool2d_4                 -     [1, 59, 2, 5]        -
# 25_features.5.Conv2d_0       [59, 70, 3, 3]     [1, 70, 2, 5]   37.24k
# 26_features.5.BatchNorm2d_1            [70]     [1, 70, 2, 5]    140.0
# 27_features.5.Dropout2d_2                 -     [1, 70, 2, 5]        -
# 28_features.5.ReLU6_3                     -     [1, 70, 2, 5]        -
# 29_features.5.MaxPool2d_4                 -     [1, 70, 1, 2]        -
# 30_features.6.Conv2d_0       [70, 81, 3, 3]     [1, 81, 1, 2]  51.111k
# 31_features.6.ReLU6_1                     -     [1, 81, 1, 2]        -
# 32_features.7.Conv2d_0       [81, 92, 3, 3]     [1, 92, 1, 2]   67.16k
# 33_features.7.ReLU6_1                     -     [1, 92, 1, 2]        -
# 34_classifier.Flatten_0                   -          [1, 184]        -
# 35_classifier.Dropout_1                   -          [1, 184]        -
# 36_classifier.Linear_2            [184, 97]           [1, 97]  17.945k
# 37_classifier.ReLU6_3                     -           [1, 97]        -
# 38_classifier.Linear_4             [97, 10]           [1, 10]    980.0
#
#                               Mult-Adds
# Layer
# 0_features.0.Conv2d_0         2.391552M
# 1_features.0.BatchNorm2d_1         24.0
# 2_features.0.Dropout2d_2              -
# 3_features.0.ReLU6_3                  -
# 4_features.0.MaxPool2d_4              -
# 5_features.1.Conv2d_0        28.532736M
# 6_features.1.BatchNorm2d_1         48.0
# 7_features.1.Dropout2d_2              -
# 8_features.1.ReLU6_3                  -
# 9_features.1.MaxPool2d_4              -
# 10_features.2.Conv2d_0       14.266368M
# 11_features.2.BatchNorm2d_1        48.0
# 12_features.2.Dropout2d_2             -
# 13_features.2.ReLU6_3                 -
# 14_features.2.MaxPool2d_4             -
# 15_features.3.Conv2d_0        3.483648M
# 16_features.3.BatchNorm2d_1        48.0
# 17_features.3.Dropout2d_2             -
# 18_features.3.ReLU6_3                 -
# 19_features.3.MaxPool2d_4             -
# 20_features.4.Conv2d_0         1.01952M
# 21_features.4.BatchNorm2d_1        59.0
# 22_features.4.Dropout2d_2             -
# 23_features.4.ReLU6_3                 -
# 24_features.4.MaxPool2d_4             -
# 25_features.5.Conv2d_0           371.7k
# 26_features.5.BatchNorm2d_1        70.0
# 27_features.5.Dropout2d_2             -
# 28_features.5.ReLU6_3                 -
# 29_features.5.MaxPool2d_4             -
# 30_features.6.Conv2d_0          102.06k
# 31_features.6.ReLU6_1                 -
# 32_features.7.Conv2d_0         134.136k
# 33_features.7.ReLU6_1                 -
# 34_classifier.Flatten_0               -
# 35_classifier.Dropout_1               -
# 36_classifier.Linear_2          17.848k
# 37_classifier.ReLU6_3                 -
# 38_classifier.Linear_4            970.0
# ----------------------------------------------------------------------------------
#                           Totals
# Total params            252.801k
# Trainable params        252.801k
# Non-trainable params         0.0
# Mult-Adds             50.320835M
# ==================================================================================

# %% [markdown]
# ## Prep training

# %%
# create model
torch.cuda.empty_cache()

model = model_func()
model.cuda()
# Out:
# cnn07(
#   (features): Sequential(
#     (0): ConvPoolReLU(
#       (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): MaxPool2d(kernel_size=(4, 2), stride=(4, 2), padding=0, dilation=1, ceil_mode=False)
#       (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU6(inplace=True)
#     )
#     (1): ConvPoolReLU(
#       (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): MaxPool2d(kernel_size=(4, 2), stride=(4, 2), padding=0, dilation=1, ceil_mode=False)
#       (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU6(inplace=True)
#     )
#     (2): ConvPoolReLU(
#       (0): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#       (2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU6(inplace=True)
#     )
#     (3): ConvPoolReLU(
#       (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#       (2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU6(inplace=True)
#     )
#     (4): ConvReLU(
#       (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Flatten()
#     (1): Dropout(p=0.5, inplace=False)
#     (2): Linear(in_features=960, out_features=256, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Dropout(p=0.5, inplace=False)
#     (5): Linear(in_features=256, out_features=10, bias=True)
#   )
# )

# %%
s_idx, u_idx = train_dataset.split_s_u(args.supervised_ratio)
S_sampler = torch.utils.data.SubsetRandomSampler(s_idx)

training_loader = torch.utils.data.DataLoader(train_dataset, batch_size=args.batch_size, sampler=S_sampler)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=args.batch_size, shuffle=True)

# %% [markdown]
# # training parameters

# %%
# tensorboard
tensorboard_title = "%s_%s_%.1fS_%s" % (get_datetime(), model_func.__name__, args.supervised_ratio, args.tensorboard_sufix)
checkpoint_title = "%s_%.1fS" % (model_func.__name__, args.supervised_ratio)
tensorboard = SummaryWriter(log_dir="%s/%s" % (args.tensorboard_path, tensorboard_title), comment=model_func.__name__)

# losses
loss_ce = nn.CrossEntropyLoss(reduction="mean")

# optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=args.learning_rate)

# callbacks
lr_lambda = lambda epoch: (1.0 + numpy.cos((epoch-1)*numpy.pi/args.nb_epoch))
lr_scheduler = LambdaLR(optimizer, lr_lambda)

# Checkpoint
checkpoint = CheckPoint(model, optimizer, mode="max", name="%s/%s.torch" % (args.checkpoint_path, checkpoint_title))

# Metrics
fscore_fn = FScore()
acc_fn = CategoricalAccuracy()
avg = ContinueAverage()

reset_metrics = lambda : [m.reset() for m in [fscore_fn, acc_fn, avg]]

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

# %% [markdown]
# ## Can resume previous training

# %%
if args.resume:
    checkpoint.load_last()

# %% [markdown]
# ## training function

# %%
UNDERLINE_SEQ = "\033[1;4m"
RESET_SEQ = "\033[0m"

header_form = "{:<8.8} {:<6.6} - {:<6.6} - {:<8.8} {:<6.6} - {:<9.9} {:<12.12}| {:<9.9}- {:<6.6}"
value_form  = "{:<8.8} {:<6} - {:<6} - {:<8.8} {:<6.4f} - {:<9.9} {:<10.4f}| {:<9.4f}- {:<6.4f}"

header = header_form.format(
    "", "Epoch", "%", "Losses:", "ce", "metrics: ", "acc", "F1 ","Time"
)

train_form = value_form
val_form = UNDERLINE_SEQ + value_form + RESET_SEQ

print(header)
# Out:
#          Epoch  - %      - Losses:  ce     - metrics:  acc         | F1       - Time

# %%
def maximum():
    def func(key, value):
        if key not in func.max:
            func.max[key] = value
        else:
            if func.max[key] < value:
                func.max[key] = value
        return func.max[key]

    func.max = dict()
    return func
maximum_fn = maximum()

# %%
def train(epoch):
    start_time = time.time()
    print("")

    reset_metrics()
    model.train()

    for i, (X, y) in enumerate(training_loader):
        X = X.cuda()
        y = y.cuda()

        logits = model(X)
        loss = loss_ce(logits, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        with torch.set_grad_enabled(False):
            pred = torch.softmax(logits, dim=1)
            pred_arg = torch.argmax(logits, dim=1)
            y_one_hot = F.one_hot(y, num_classes=10)

            acc = acc_fn(pred_arg, y).mean
            fscore = fscore_fn(pred, y_one_hot).mean
            avg_ce = avg(loss.item()).mean

            # logs
            print(train_form.format(
                "Training: ",
                epoch + 1,
                int(100 * (i + 1) / len(training_loader)),
                "", avg_ce,
                "", acc, fscore,
                time.time() - start_time
            ), end="\r")

    tensorboard.add_scalar("train/Lce", avg_ce, epoch)
    tensorboard.add_scalar("train/f1", fscore, epoch)
    tensorboard.add_scalar("train/acc", acc, epoch)

# %%
def val(epoch):
    start_time = time.time()
    print("")
    reset_metrics()
    model.eval()

    for i, (X, y) in enumerate(val_loader):
        X = X.cuda()
        y = y.cuda()

        logits = model(X)
        loss = loss_ce(logits, y)

        with torch.set_grad_enabled(False):
            pred = torch.softmax(logits, dim=1)
            pred_arg = torch.argmax(logits, dim=1)
            y_one_hot = F.one_hot(y, num_classes=10)

            acc = acc_fn(pred_arg, y).mean
            fscore = fscore_fn(pred, y_one_hot).mean
            avg_ce = avg(loss.item()).mean

            # logs
            print(val_form.format(
                "Validation: ",
                epoch + 1,
                int(100 * (i + 1) / len(val_loader)),
                "", avg_ce,
                "", acc, fscore,
                time.time() - start_time
            ), end="\r")

    tensorboard.add_scalar("val/Lce", avg_ce, epoch)
    tensorboard.add_scalar("val/f1", fscore, epoch)
    tensorboard.add_scalar("val/acc", acc, epoch)

    tensorboard.add_scalar("max/f1", maximum_fn("fscore", fscore), epoch )
    tensorboard.add_scalar("max/acc", maximum_fn("acc", acc), epoch )

    tensorboard.add_scalar("hyperparameters/learning_rate", get_lr(optimizer), epoch)

    checkpoint.step(acc)
    lr_scheduler.step()

# %%
print(header)

start_epoch = checkpoint.epoch_counter
end_epoch = args.nb_epoch

for e in range(start_epoch, args.nb_epoch):
    train(e)
    val(e)

tensorboard.flush()
tensorboard.close()
# Out:
#          Epoch  - %      - Losses:  ce     - metrics:  acc         | F1       - Time
#
# Training 1      - 100    -          1.7510 -           0.3530    | 0.2027   - 47.6553
# Validati 1      - 100    -          1.5187 -           0.4581    | 0.2465   - 4.7405
#  better performance: saving ...
#
# Training 2      - 100    -          1.4810 -           0.4572    | 0.3454   - 3.7519
# Validati 2      - 100    -          1.3632 -           0.5102    | 0.4020   - 0.1475
#  better performance: saving ...
#
# Training 3      - 100    -          1.2396 -           0.5687    | 0.4938   - 3.5014
# Validati 3      - 100    -          1.1689 -           0.5963    | 0.5325   - 0.1284
#  better performance: saving ...
#
# Training 4      - 100    -          1.1013 -           0.6419    | 0.5916   - 3.5514
# Validati 4      - 100    -          1.6847 -           0.4850    | 0.4882   - 0.1397
# Training 5      - 100    -          0.9654 -           0.6860    | 0.6580   - 3.4296
# Validati 5      - 100    -          1.0718 -           0.6442    | 0.6426   - 0.1139
#  better performance: saving ...
#
# Training 6      - 100    -          0.8495 -           0.7301    | 0.7102   - 3.1014
# Validati 6      - 100    -          1.1017 -           0.6324    | 0.6158   - 0.1144
# Training 7      - 100    -          0.7623 -           0.7612    | 0.7476   - 3.3959
# Validati 7      - 100    -          2.5630 -           0.3708    | 0.3799   - 0.1243
# Training 8      - 100    -          0.7431 -           0.7654    | 0.7571   - 3.4025
# Validati 8      - 100    -          1.1192 -           0.6373    | 0.6198   - 0.1142
# Training 9      - 100    -          0.6991 -           0.7803    | 0.7721   - 3.3700
# Validati 9      - 100    -          1.3499 -           0.6333    | 0.6218   - 0.1328
# Training 10     - 100    -          0.6533 -           0.7969    | 0.7911   - 3.6238
# Validati 10     - 100    -          1.5872 -           0.5782    | 0.5853   - 0.1442
# Training 11     - 100    -          0.6576 -           0.7959    | 0.7879   - 3.4290
# Validati 11     - 100    -          2.6111 -           0.4678    | 0.4716   - 0.1216
# Training 12     - 100    -          0.6082 -           0.8076    | 0.8023   - 3.4362
# Validati 12     - 100    -          1.2471 -           0.6558    | 0.6682   - 0.1235
#  better performance: saving ...
#
# Training 13     - 100    -          0.5870 -           0.8188    | 0.8117   - 3.4189
# Validati 13     - 100    -          1.2112 -           0.6778    | 0.6658   - 0.1231
#  better performance: saving ...
#
# Training 14     - 100    -          0.5515 -           0.8262    | 0.8221   - 3.3995
# Validati 14     - 100    -          0.9231 -           0.7014    | 0.7132   - 0.1144
#  better performance: saving ...
#
# Training 15     - 100    -          0.5478 -           0.8233    | 0.8231   - 3.3492
# Validati 15     - 100    -          0.8160 -           0.7611    | 0.7540   - 0.1178
#  better performance: saving ...
#
# Training 16     - 100    -          0.5270 -           0.8371    | 0.8314   - 3.4854
# Validati 16     - 100    -          1.0919 -           0.7148    | 0.7143   - 0.1270
# Training 17     - 100    -          0.5192 -           0.8387    | 0.8355   - 3.4532
# Validati 17     - 100    -          0.9934 -           0.7484    | 0.7473   - 0.1276
# Training 18     - 100    -          0.4831 -           0.8470    | 0.8477   - 3.6812
# Validati 18     - 100    -          1.1282 -           0.7102    | 0.7143   - 0.1224
# Training 19     - 100    -          0.5076 -           0.8414    | 0.8387   - 3.4304
# Validati 19     - 100    -          0.8210 -           0.7900    | 0.7906   - 0.1215
#  better performance: saving ...
#
# Training 20     - 100    -          0.4766 -           0.8526    | 0.8467   - 3.4153
# Validati 20     - 100    -          0.9300 -           0.7815    | 0.7700   - 0.1140
# Training 21     - 100    -          0.4736 -           0.8594    | 0.8542   - 3.5177
# Validati 21     - 100    -          1.0176 -           0.6998    | 0.7069   - 0.1427
# Training 22     - 100    -          0.4626 -           0.8628    | 0.8627   - 3.5362
# Validati 22     - 100    -          1.0816 -           0.7144    | 0.7100   - 0.1193
# Training 23     - 100    -          0.3936 -           0.8806    | 0.8802   - 3.3772
# Validati 23     - 100    -          1.0045 -           0.7553    | 0.7649   - 0.1130
# Training 24     - 100    -          0.3763 -           0.8867    | 0.8870   - 3.4142
# Validati 24     - 100    -          1.3489 -           0.7488    | 0.7516   - 0.1214
# Training 25     - 100    -          0.4257 -           0.8761    | 0.8732   - 3.4568
# Validati 25     - 100    -          1.2133 -           0.6664    | 0.6623   - 0.1133
# Training 26     - 100    -          0.3941 -           0.8856    | 0.8853   - 3.3479
# Validati 26     - 100    -          1.0603 -           0.7579    | 0.7274   - 0.1140
# Training 27     - 100    -          0.4076 -           0.8863    | 0.8840   - 3.5851
# Validati 27     - 100    -          1.7347 -           0.6144    | 0.6102   - 0.1311
# Training 28     - 100    -          0.3655 -           0.8893    | 0.8895   - 3.4003
# Validati 28     - 100    -          0.9000 -           0.7583    | 0.7553   - 0.1170
# Training 29     - 100    -          0.3279 -           0.9013    | 0.9037   - 3.1846
# Validati 29     - 100    -          0.9615 -           0.8102    | 0.8200   - 0.1191
#  better performance: saving ...
#
# Training 30     - 100    -          0.3458 -           0.9016    | 0.8985   - 3.1919
# Validati 30     - 100    -          1.0562 -           0.7264    | 0.7253   - 0.1142
# Training 31     - 100    -          0.3436 -           0.9013    | 0.9026   - 3.6047
# Validati 31     - 100    -          0.9528 -           0.7630    | 0.7673   - 0.1232
# Training 32     - 100    -          0.3060 -           0.9095    | 0.9107   - 3.4877
# Validati 32     - 100    -          1.1601 -           0.7120    | 0.7193   - 0.1324
# Training 33     - 100    -          0.3093 -           0.9134    | 0.9149   - 3.5663
# Validati 33     - 100    -          1.4320 -           0.6894    | 0.7024   - 0.1246
# Training 34     - 100    -          0.3080 -           0.9096    | 0.9103   - 3.4293
# Validati 34     - 100    -          1.9660 -           0.6160    | 0.6180   - 0.1142
# Training 35     - 100    -          0.2801 -           0.9193    | 0.9187   - 3.4916
# Validati 35     - 100    -          0.9509 -           0.7912    | 0.7808   - 0.1300
# Training 36     - 100    -          0.3054 -           0.9179    | 0.9175   - 3.4087
# Validati 36     - 100    -          0.8951 -           0.8062    | 0.8148   - 0.1226
# Training 37     - 100    -          0.2591 -           0.9273    | 0.9263   - 3.4290
# Validati 37     - 100    -          1.8162 -           0.6306    | 0.6379   - 0.1202
# Training 38     - 100    -          0.2554 -           0.9280    | 0.9281   - 3.4523
# Validati 38     - 100    -          1.1676 -           0.7549    | 0.7563   - 0.1118
# Training 39     - 100    -          0.2504 -           0.9282    | 0.9288   - 3.4008
# Validati 39     - 100    -          1.1355 -           0.7755    | 0.7770   - 0.1278
# Training 40     - 100    -          0.2479 -           0.9276    | 0.9288   - 3.6073
# Validati 40     - 100    -          1.0022 -           0.7650    | 0.7673   - 0.1267
# Training 41     - 100    -          0.2632 -           0.9281    | 0.9275   - 3.5886
# Validati 41     - 100    -          1.4800 -           0.7368    | 0.7414   - 0.1267
# Training 42     - 100    -          0.2262 -           0.9333    | 0.9342   - 3.4998
# Validati 42     - 100    -          1.6787 -           0.7120    | 0.7029   - 0.1271
# Training 43     - 100    -          0.2304 -           0.9317    | 0.9318   - 3.5968
# Validati 43     - 100    -          2.0968 -           0.5928    | 0.6027   - 0.1279
# Training 44     - 100    -          0.2125 -           0.9388    | 0.9394   - 3.4939
# Validati 44     - 100    -          1.2537 -           0.8062    | 0.8149   - 0.1245
# Training 45     - 100    -          0.1840 -           0.9454    | 0.9468   - 3.5487
# Validati 45     - 100    -          1.1300 -           0.7688    | 0.7731   - 0.1321
# Training 46     - 100    -          0.2032 -           0.9447    | 0.9438   - 3.5358
# Validati 46     - 100    -          1.3308 -           0.7525    | 0.7626   - 0.1296
# Training 47     - 100    -          0.1604 -           0.9509    | 0.9522   - 3.4150
# Validati 47     - 100    -          2.1650 -           0.6650    | 0.6792   - 0.1144
# Training 48     - 100    -          0.1749 -           0.9476    | 0.9484   - 3.5757
# Validati 48     - 100    -          1.0321 -           0.8021    | 0.8085   - 0.1216
# Training 49     - 100    -          0.1712 -           0.9522    | 0.9519   - 3.4047
# Validati 49     - 100    -          1.0604 -           0.7826    | 0.7946   - 0.1217
# Training 50     - 100    -          0.1748 -           0.9507    | 0.9504   - 3.4389
# Validati 50     - 100    -          1.8884 -           0.7299    | 0.7325   - 0.1343
# Training 51     - 100    -          0.2054 -           0.9409    | 0.9417   - 3.4087
# Validati 51     - 100    -          1.0441 -           0.8113    | 0.8121   - 0.1147
#  better performance: saving ...
#
# Training 52     - 100    -          0.1558 -           0.9534    | 0.9539   - 3.4364
# Validati 52     - 100    -          1.3291 -           0.7894    | 0.7994   - 0.1288
# Training 53     - 100    -          0.1443 -           0.9598    | 0.9599   - 3.5478
# Validati 53     - 100    -          1.7060 -           0.7421    | 0.7436   - 0.1159
# Training 54     - 100    -          0.1817 -           0.9540    | 0.9534   - 3.5194
# Validati 54     - 100    -          1.3381 -           0.7766    | 0.7807   - 0.1252
# Training 55     - 100    -          0.1633 -           0.9552    | 0.9564   - 3.4378
# Validati 55     - 100    -          1.0579 -           0.7993    | 0.8034   - 0.1135
# Training 56     - 100    -          0.1325 -           0.9646    | 0.9640   - 3.4832
# Validati 56     - 100    -          1.2641 -           0.8074    | 0.8160   - 0.1215
# Training 57     - 100    -          0.1465 -           0.9588    | 0.9590   - 3.5409
# Validati 57     - 100    -          1.0961 -           0.7866    | 0.7959   - 0.1240
# Training 58     - 100    -          0.1284 -           0.9600    | 0.9616   - 3.4385
# Validati 58     - 100    -          1.2408 -           0.8148    | 0.8216   - 0.1238
#  better performance: saving ...
#
# Training 59     - 100    -          0.1180 -           0.9654    | 0.9662   - 3.5154
# Validati 59     - 100    -          1.3479 -           0.7993    | 0.8095   - 0.1176
# Training 60     - 100    -          0.1015 -           0.9686    | 0.9684   - 3.4428
# Validati 60     - 100    -          1.3741 -           0.8058    | 0.8160   - 0.1239
# Training 61     - 100    -          0.1136 -           0.9671    | 0.9673   - 3.4267
# Validati 61     - 100    -          1.5750 -           0.7669    | 0.7717   - 0.1268
# Training 62     - 100    -          0.1152 -           0.9676    | 0.9687   - 3.5405
# Validati 62     - 100    -          1.3206 -           0.7961    | 0.8099   - 0.1241
# Training 63     - 100    -          0.0989 -           0.9715    | 0.9712   - 3.4754
# Validati 63     - 100    -          1.2407 -           0.8125    | 0.8239   - 0.1253
# Training 64     - 100    -          0.0964 -           0.9714    | 0.9722   - 3.5783
# Validati 64     - 100    -          1.4732 -           0.8046    | 0.8128   - 0.1288
# Training 65     - 100    -          0.1165 -           0.9673    | 0.9674   - 3.4271
# Validati 65     - 100    -          1.2343 -           0.8132    | 0.8210   - 0.1278
# Training 66     - 100    -          0.1048 -           0.9691    | 0.9701   - 3.4396
# Validati 66     - 100    -          1.6270 -           0.7560    | 0.7636   - 0.1172
# Training 67     - 100    -          0.1093 -           0.9698    | 0.9698   - 3.5912
# Validati 67     - 100    -          1.2373 -           0.8005    | 0.8133   - 0.1468
# Training 68     - 100    -          0.0877 -           0.9746    | 0.9735   - 3.4995
# Validati 68     - 100    -          1.3255 -           0.8178    | 0.8316   - 0.1219
#  better performance: saving ...
#
# Training 69     - 100    -          0.0836 -           0.9766    | 0.9765   - 3.4361
# Validati 69     - 100    -          1.3642 -           0.8109    | 0.8197   - 0.1310
# Training 70     - 100    -          0.0866 -           0.9767    | 0.9775   - 3.5810
# Validati 70     - 100    -          1.6346 -           0.8058    | 0.8116   - 0.1136
# Training 71     - 100    -          0.0934 -           0.9740    | 0.9734   - 3.4104
# Validati 71     - 100    -          1.3600 -           0.7900    | 0.7941   - 0.1228
# Training 72     - 100    -          0.0671 -           0.9796    | 0.9794   - 3.6067
# Validati 72     - 100    -          1.4420 -           0.7926    | 0.7993   - 0.1243
# Training 73     - 100    -          0.0759 -           0.9765    | 0.9757   - 3.4088
# Validati 73     - 100    -          1.5509 -           0.8097    | 0.8158   - 0.1146
# Training 74     - 100    -          0.0596 -           0.9814    | 0.9820   - 3.4542
# Validati 74     - 100    -          1.3627 -           0.8178    | 0.8248   - 0.1284
#  better performance: saving ...
#
# Training 75     - 100    -          0.0608 -           0.9819    | 0.9815   - 3.2996
# Validati 75     - 100    -          1.5173 -           0.8183    | 0.8223   - 0.1248
#  better performance: saving ...
#
# Training 76     - 100    -          0.0610 -           0.9803    | 0.9799   - 3.4477
# Validati 76     - 100    -          1.5169 -           0.8113    | 0.8227   - 0.1284
# Training 77     - 100    -          0.0551 -           0.9830    | 0.9839   - 3.6341
# Validati 77     - 100    -          1.7048 -           0.7981    | 0.8052   - 0.1211
# Training 78     - 100    -          0.0587 -           0.9814    | 0.9825   - 3.3877
# Validati 78     - 100    -          1.4269 -           0.8160    | 0.8234   - 0.1189
# Training 79     - 100    -          0.0656 -           0.9822    | 0.9818   - 3.6328
# Validati 79     - 100    -          1.3473 -           0.8229    | 0.8285   - 0.1249
#  better performance: saving ...
#
# Training 80     - 100    -          0.0520 -           0.9843    | 0.9845   - 3.4491
# Validati 80     - 100    -          1.4099 -           0.8062    | 0.8132   - 0.1242
# Training 81     - 100    -          0.0587 -           0.9838    | 0.9841   - 3.5191
# Validati 81     - 100    -          1.3739 -           0.8201    | 0.8274   - 0.1162
# Training 82     - 100    -          0.0498 -           0.9864    | 0.9863   - 3.4677
# Validati 82     - 100    -          1.5440 -           0.8132    | 0.8224   - 0.1268
# Training 83     - 100    -          0.0505 -           0.9847    | 0.9847   - 3.4480
# Validati 83     - 100    -          1.3914 -           0.8229    | 0.8297   - 0.1438
#  better performance: saving ...
#
# Training 84     - 100    -          0.0423 -           0.9860    | 0.9860   - 3.4716
# Validati 84     - 100    -          1.4990 -           0.8144    | 0.8190   - 0.1278
# Training 85     - 100    -          0.0503 -           0.9844    | 0.9848   - 3.4532
# Validati 85     - 100    -          1.5081 -           0.8127    | 0.8183   - 0.1307
# Training 86     - 100    -          0.0457 -           0.9849    | 0.9851   - 3.5125
# Validati 86     - 100    -          1.4909 -           0.8252    | 0.8316   - 0.1134
#  better performance: saving ...
#
# Training 87     - 100    -          0.0392 -           0.9875    | 0.9873   - 3.5759
# Validati 87     - 100    -          1.5720 -           0.8120    | 0.8210   - 0.1233
# Training 88     - 100    -          0.0429 -           0.9852    | 0.9856   - 3.5156
# Validati 88     - 100    -          1.4774 -           0.8264    | 0.8303   - 0.1304
#  better performance: saving ...
#
# Training 89     - 100    -          0.0361 -           0.9879    | 0.9879   - 3.4511
# Validati 89     - 100    -          1.6110 -           0.8093    | 0.8138   - 0.1183
# Training 90     - 100    -          0.0362 -           0.9882    | 0.9881   - 3.6026
# Validati 90     - 100    -          1.5898 -           0.8229    | 0.8276   - 0.1277
# Training 91     - 100    -          0.0442 -           0.9876    | 0.9875   - 3.4564
# Validati 91     - 100    -          1.5295 -           0.8160    | 0.8247   - 0.1286
# Training 92     - 100    -          0.0378 -           0.9889    | 0.9894   - 3.4734
# Validati 92     - 100    -          1.5663 -           0.8218    | 0.8283   - 0.1260
# Training 93     - 100    -          0.0363 -           0.9891    | 0.9891   - 3.3149
# Validati 93     - 100    -          1.8173 -           0.8116    | 0.8146   - 0.1241
# Training 94     - 100    -          0.0432 -           0.9884    | 0.9883   - 3.1122
# Validati 94     - 100    -          1.6776 -           0.8155    | 0.8250   - 0.1242
# Training 95     - 100    -          0.0340 -           0.9874    | 0.9874   - 3.4629
# Validati 95     - 100    -          1.5990 -           0.8264    | 0.8267   - 0.1189
#  better performance: saving ...
#
# Training 96     - 100    -          0.0433 -           0.9878    | 0.9877   - 3.4080
# Validati 96     - 100    -          1.6242 -           0.8076    | 0.8114   - 0.1233
# Training 97     - 100    -          0.0378 -           0.9889    | 0.9887   - 3.4907
# Validati 97     - 100    -          1.4954 -           0.8236    | 0.8276   - 0.1193
# Training 98     - 100    -          0.0407 -           0.9880    | 0.9883   - 3.4585
# Validati 98     - 100    -          1.5140 -           0.8275    | 0.8316   - 0.1303
#  better performance: saving ...
#
# Training 99     - 100    -          0.0380 -           0.9887    | 0.9886   - 3.4503
# Validati 99     - 100    -          1.6560 -           0.8275    | 0.8349   - 0.1300
#  better performance: saving ...
#
# Training 100    - 100    -          0.0401 -           0.9882    | 0.9879   - 3.5197
# Validati 100    - 100    -          1.5672 -           0.8167    | 0.8240   - 0.1245

# %% [markdown]
# # ♫♪.ılılıll|̲̅̅●̲̅̅|̲̅̅=̲̅̅|̲̅̅●̲̅̅|llılılı.♫♪
